# %%
from fastlane_bot import Config, ConfigDB, ConfigNetwork, ConfigProvider, Bot
from web3 import Web3
from fastlane_bot.data.abi import CARBON_CONTROLLER_ABI

print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(Config))
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(Bot))
from fastlane_bot.testing import *

from fastlane_bot import __VERSION__
require("2.0", __VERSION__)
# Out:
# Config v1.0-BETA8 (01/May 2023)
# CarbonBot v2.0-BETA4 (30/Apr/2023)
# imported m, np, pd, plt, os, sys, decimal; defined iseq, raises, require
# Version = 2.0-BETA4 [requirements >= 2.0 is met]

# %%
# raise

# %% [markdown]
# # BOT TEMPLATE [NBTest010]

# %% [markdown]
# ## Mainnet Alchemy [NOTEST]

# %%
C = Config.new(config=Config.CONFIG_MAINNET)
assert C.DATABASE == C.DATABASE_POSTGRES
assert C.POSTGRES_DB == "mainnet"
assert C.NETWORK == C.NETWORK_MAINNET
assert C.PROVIDER == C.PROVIDER_ALCHEMY
print("Web3 API:", C.w3.api)
# Out:
# Web3 API: 5.31.3

# %% [markdown]
# ## Tenderly [NOTEST]

# %%
pass

# %% [markdown]
# ## Mainnet Alchemy Configuration

# %%
C = Config.new(config=Config.CONFIG_MAINNET)
assert C.DATABASE == C.DATABASE_POSTGRES
assert C.POSTGRES_DB == "mainnet"
assert C.NETWORK == C.NETWORK_MAINNET
assert C.PROVIDER == C.PROVIDER_ALCHEMY
assert C.w3.__class__.__name__ == "Web3"
assert C.w3.isConnected()
assert C.w3.provider.endpoint_uri.startswith("https://eth-mainnet.alchemyapi.io/v2")

# %%
bot = Bot(ConfigObj=C)
# Out:
# Using default database url: postgresql://postgres:b2742bade1f3a271c55eef069e2f19903aa0740c@localhost/mainnet
# 2023-05-01 19:35:27,713 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)
# 2023-05-01 19:35:27,713 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)

# %%
# bot.update_pools()

# %%
# bot.drop_tables()

# %% [markdown]
# ## Unittest Configuration

# %%
C = Config.new(config=Config.CONFIG_UNITTEST)
assert C.DATABASE == C.DATABASE_UNITTEST
assert C.NETWORK == C.NETWORK_MAINNET
#assert C.PROVIDER == C.PROVIDER_UNITTEST
assert C.PROVIDER == C.PROVIDER_ALCHEMY

# %%
bot = Bot(ConfigObj=C)
# Out:
# Using default database url: postgresql://postgres:b2742bade1f3a271c55eef069e2f19903aa0740c@localhost/unittest
# 2023-05-01 19:35:29,318 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/unittest)
# 2023-05-01 19:35:29,318 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/unittest)
# 2023-05-01 19:35:29,318 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/unittest)

# %% [markdown]
# ## Mainnet Alchemy change DB

# %%
C_nw = ConfigNetwork.new(network=ConfigNetwork.NETWORK_MAINNET)
C_db = ConfigDB.new(db=ConfigDB.DATABASE_POSTGRES, POSTGRES_DB="postgres")
C_pr = ConfigProvider.new(network=C_nw)
C = Config(db = C_db, network = C_nw, provider = C_pr)
assert C_db.POSTGRES_URL.endswith("/postgres")
assert C.DATABASE == C.DATABASE_POSTGRES
assert C.POSTGRES_DB == "postgres"
assert C.NETWORK == C.NETWORK_MAINNET
assert C.PROVIDER == C.PROVIDER_ALCHEMY
assert C.w3.__class__.__name__ == "Web3"
C
# Out:
# Config(network=_ConfigNetworkMainnet(), db=_ConfigDBPostgres(), logger=_ConfigLoggerDefault(), provider=_ConfigProviderAlchemy())

# %%
bot = Bot(ConfigObj=C)
# Out:
# Using default database url: postgresql://postgres:b2742bade1f3a271c55eef069e2f19903aa0740c@localhost/postgres
# 2023-05-01 19:35:30,928 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/postgres)
# 2023-05-01 19:35:30,928 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/postgres)
# 2023-05-01 19:35:30,928 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/postgres)
# 2023-05-01 19:35:30,928 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/postgres)

# %% [markdown]
# ## Bot update on the mainnet [NOTEST]

# %%
C = Config.new(config=Config.CONFIG_MAINNET)
assert C.DATABASE == C.DATABASE_POSTGRES
assert C.POSTGRES_DB == "mainnet"
assert C.NETWORK == C.NETWORK_MAINNET
assert C.PROVIDER == C.PROVIDER_ALCHEMY
assert C.w3.__class__.__name__ == "Web3"
assert C.w3.isConnected()
assert C.w3.provider.endpoint_uri.startswith("https://eth-mainnet.alchemyapi.io/v2")
bot = Bot(ConfigObj=C)
# Out:
# Using default database url: postgresql://postgres:b2742bade1f3a271c55eef069e2f19903aa0740c@localhost/mainnet
# 2023-05-01 19:35:32,632 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)
# 2023-05-01 19:35:32,632 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)
# 2023-05-01 19:35:32,632 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)
# 2023-05-01 19:35:32,632 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)
# 2023-05-01 19:35:32,632 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)

# %%
bot.update(drop_tables=False)
# Out:
# 2023-05-01 19:35:38,741 [fastlane:INFO] - [model_managers.Token] Created token: BNT-FF1C
# 2023-05-01 19:35:38,741 [fastlane:INFO] - [model_managers.Token] Created token: BNT-FF1C
# 2023-05-01 19:35:38,741 [fastlane:INFO] - [model_managers.Token] Created token: BNT-FF1C
# 2023-05-01 19:35:38,741 [fastlane:INFO] - [model_managers.Token] Created token: BNT-FF1C
# 2023-05-01 19:35:38,741 [fastlane:INFO] - [model_managers.Token] Created token: BNT-FF1C
# 2023-05-01 19:35:39,692 [fastlane:INFO] - [model_managers.Token] Created token: DEXE-Cbd6
# 2023-05-01 19:35:39,692 [fastlane:INFO] - [model_managers.Token] Created token: DEXE-Cbd6
# 2023-05-01 19:35:39,692 [fastlane:INFO] - [model_managers.Token] Created token: DEXE-Cbd6
# 2023-05-01 19:35:39,692 [fastlane:INFO] - [model_managers.Token] Created token: DEXE-Cbd6
# 2023-05-01 19:35:39,692 [fastlane:INFO] - [model_managers.Token] Created token: DEXE-Cbd6
# 2023-05-01 19:35:39,936 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:35:39,936 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:35:39,936 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:35:39,936 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:35:39,936 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:35:40,150 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:35:40,150 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:35:40,150 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:35:40,150 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:35:40,150 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/
[fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xfA5047c9c78B8877af97BDcb85Db743fD7313d4a on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:37:25,929 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xfA5047c9c78B8877af97BDcb85Db743fD7313d4a on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:37:25,929 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xfA5047c9c78B8877af97BDcb85Db743fD7313d4a on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:37:25,929 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xfA5047c9c78B8877af97BDcb85Db743fD7313d4a on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:37:25,929 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xfA5047c9c78B8877af97BDcb85Db743fD7313d4a on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f5def29c8d00> in <module>
# ----> 1 bot.update(drop_tables=True)
#
# ~/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/bot.py in update(self, udtype, drop_tables)
#     183
#     184         if udtype == self.UDTYPE_FROM_CONTRACTS:
# --> 185             return self.db.update_pools_from_contracts()
#     186         elif udtype == self.UDTYPE_FROM_EVENTS:
#     187             return self.db.update_pools_from_events()
#
# ~/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/db/manager.py in update_pools_from_contracts(self)
#      88
#      89         if not pools:
# ---> 90             self.create_pools_from_contracts()
#      91
#      92         for exchange in self.ConfigObj.SUPPORTED_EXCHANGES:
#
# ~/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/db/manager.py in create_pools_from_contracts(self)
#     482                 if exchange == self.ConfigObj.BANCOR_V3_NAME:
#     483                     contract = self.c.BANCOR_NETWORK_INFO_CONTRACT
# --> 484                     self.create_or_update_pool_with_multicall(
#     485                         [(exchange, address, contract) for address in pool_addresses]
#     486                     )
#
# ~/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/db/manager.py in create_or_update_pool_with_multicall(self, pools)
#     657                     pool = self.get_pool(exchange_name=exchange_name, address=pool_address)
#     658                     if not pool:
# --> 659                         params = self.build_pool_params(exchange_name=exchange_name, pool_address=pool_address)
#     660                         self.create_pool(params)
#     661                     else:
#
# ~/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/db/manager.py in build_pool_params(self, exchange_name, pool_address, pool_contract)
#     617             )
#     618             tkn0 = self.get_or_create_token(tkn0_address)
# --> 619             tkn1 = self.get_or_create_token(tkn1_address)
#     620             pair = self.get_or_create_pair(tkn0_address, tkn1_address)
#     621             common_data = dict(
#
# ~/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/db/manager.py in get_or_create_token(self, address)
#     269             try:
#     270                 contract = self.ConfigObj.w3.eth.contract(address=address, abi=_abi.ERC20_ABI)
# --> 271                 symbol = contract.caller.symbol()
#     272                 tkn_key = f"{symbol}-{address[-4:]}"
#     273                 token = models.Token(address=address, name=contract.caller.name(), symbol=symbol,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/contract.py in call_function(fn, transaction, block_identifier, *args, **kwargs)
#    1475         if transaction is None:
#    1476             transaction = {}
# -> 1477         return fn(*args, **kwargs).call(transaction, block_identifier)
#    1478
#    1479
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/contract.py in call(self, transaction, block_identifier, state_override)
#     968         block_id = parse_block_identifier(self.web3, block_identifier)
#     969
# --> 970         return call_contract_function(
#     971             self.web3,
#     972             self.address,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/contract.py in call_contract_function(web3, address, normalizers, function_identifier, transaction, block_id, contract_abi, fn_abi, state_override, *args, **kwargs)
#    1523     )
#    1524
# -> 1525     return_data = web3.eth.call(
#    1526         call_transaction,
#    1527         block_identifier=block_id,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/module.py in caller(*args, **kwargs)
#      55             return LogFilter(eth_module=module, filter_id=err.filter_id)
#      56         result_formatters, error_formatters, null_result_formatters = response_formatters
# ---> 57         result = w3.manager.request_blocking(method_str,
#      58                                              params,
#      59                                              error_formatters,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/manager.py in request_blocking(self, method, params, error_formatters, null_result_formatters)
#     195         Make a synchronous request using the provider
#     196         """
# --> 197         response = self._make_request(method, params)
#     198         return self.formatted_response(response,
#     199                                        params,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/manager.py in _make_request(self, method, params)
#     148             self.middleware_onion)
#     149         self.logger.debug("Making request. Method: %s", method)
# --> 150         return request_func(method, params)
#     151
#     152     async def _coro_make_request(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/middleware/gas_price_strategy.py in middleware(method, params)
#      88             )
#      89             return make_request(method, (transaction,))
# ---> 90         return make_request(method, params)
#      91
#      92     return middleware
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/middleware/attrdict.py in middleware(method, params)
#      31     """
#      32     def middleware(method: RPCEndpoint, params: Any) -> RPCResponse:
# ---> 33         response = make_request(method, params)
#      34
#      35         if 'result' in response:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/middleware/formatting.py in middleware(method, params)
#      92                 formatter = request_formatters[method]
#      93                 params = formatter(params)
# ---> 94             response = make_request(method, params)
#      95
#      96             return _apply_response_formatters(method=method, response=response, **formatters)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/middleware/buffered_gas_estimate.py in middleware(method, params)
#      38                 )
#      39                 return make_request(method, [transaction])
# ---> 40         return make_request(method, params)
#      41     return middleware
#      42
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/middleware/exception_retry_request.py in middleware(method, params)
#     103             for i in range(retries):
#     104                 try:
# --> 105                     return make_request(method, params)
#     106                 # https://github.com/python/mypy/issues/5349
#     107                 except errors:  # type: ignore
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/providers/rpc.py in make_request(self, method, params)
#      86                           self.endpoint_uri, method)
#      87         request_data = self.encode_rpc_request(method, params)
# ---> 88         raw_response = make_post_request(
#      89             self.endpoint_uri,
#      90             request_data,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/web3/_utils/request.py in make_post_request(endpoint_uri, data, *args, **kwargs)
#     110     session = _get_session(endpoint_uri)
#     111     # https://github.com/python/mypy/issues/2582
# --> 112     response = session.post(endpoint_uri, data=data, *args, **kwargs)  # type: ignore
#     113     response.raise_for_status()
#     114
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     633         """
#     634
# --> 635         return self.request("POST", url, data=data, json=json, **kwargs)
#     636
#     637     def put(self, url, data=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
