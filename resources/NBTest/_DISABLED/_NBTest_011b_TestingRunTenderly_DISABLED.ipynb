# %%
from fastlane_bot import Config, ConfigDB, ConfigNetwork, ConfigProvider
from fastlane_bot.bot import CarbonBot
from fastlane_bot.tools.cpc import ConstantProductCurve as CPC, CPCContainer, T
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(CPC))
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(CarbonBot))
from fastlane_bot.testing import *
plt.style.use('seaborn-dark')
plt.rcParams['figure.figsize'] = [12,6]
from fastlane_bot import __VERSION__
require("2.0", __VERSION__)
# Out:
# ConstantProductCurve v2.7 (02/May/2023)
# CarbonBot v2.0-BETA6 (03/May/2023)
# imported m, np, pd, plt, os, sys, decimal; defined iseq, raises, require
# Version = 2.0-BETA6 [requirements >= 2.0 is met]

# %% [markdown]
# # Testing the _run functions on TENDERLY [NBTest011b]

# %% [markdown]
# ## TENDERLY Configuration

# %%
ADDRDEC = dict(
    USDC=("0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48", 6),
    WETH=("0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2", 18),
)

# %%
C_nw = ConfigNetwork.new(network=ConfigNetwork.NETWORK_TENDERLY)
c1, c2 = C_nw.shellcommand().splitlines()
print(c1)
print(c2)
# !{c1}
# !{c2}
# Out:
# brownie networks delete tenderly
# brownie networks add "Ethereum" "tenderly" host=https://rpc.tenderly.co/fork/058b12b9-c69e-4676-a7bd-2ba09c9b23c7 chainid=1

# %% [markdown]
# ### Set up the bot and curves

# %%
C = Config.new(config=Config.CONFIG_TENDERLY)
bot = CarbonBot(ConfigObj=C)
assert C.DATABASE == C.DATABASE_POSTGRES
assert C.POSTGRES_DB == "tenderly"
assert C.NETWORK == C.NETWORK_TENDERLY
assert C.PROVIDER == C.PROVIDER_TENDERLY
assert C.w3.provider.endpoint_uri.startswith("https://rpc.tenderly.co/fork/")
assert len(bot.db.get_carbon_pairs()) > 10
assert bot.db.carbon_controller.address == '0xC537e898CD774e2dCBa3B14Ea6f34C93d5eA45e1'
assert str(type(bot.db)) == "<class 'fastlane_bot.db.manager.DatabaseManager'>"
# Out:
# Using default database url: postgresql://postgres:b2742bade1f3a271c55eef069e2f19903aa0740c@localhost/tenderly
# 2023-05-03 06:56:45,970 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/tenderly)

# %%
#provided here for convenience; must be commented out for tests
bot.update(drop_tables=True, only_carbon=False, top_n=100)
# Out:
# 2023-05-03 06:56:46,312 [fastlane:INFO] - starting update(udtype=None, drop_tables=True, top_n=100, only_carbon=False)
# 2023-05-03 06:56:53,108 [fastlane:INFO] - [model_managers.Token] Successfully created token: BNT-FF1C
# 2023-05-03 06:56:54,369 [fastlane:INFO] - [model_managers.Token] Successfully created token: DEXE-Cbd6
# 2023-05-03 06:56:54,825 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 1
# 2023-05-03 06:56:55,022 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/DEXE-Cbd6
# 2023-05-03 06:56:56,847 [fastlane:INFO] - [model_managers.Token] Successfully created token: COMP-6888
# 2023-05-03 06:56:57,411 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 2
# 2023-05-03 06:56:57,600 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: COMP-6888/BNT-FF1C
# 2023-05-03 06:56:59,547 [fastlane:INFO] - [model_managers.Token] Successfully created token: COT-9ff8
# 2023-05-03 06:57:00,010 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 3
# 2023-05-03 06:57:00,193 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/COT-9ff8
# 2023-05-03 06:57:02,394 [fastlane:INFO] - [model_managers.Token] Successfully created token: DAO-09Ad
# 2023-05-03 06:57:02,846 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 4
# 2023-05-03 06:57:03,038 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/DAO-09Ad
# 2023-05-03 06:57:05,153 [fastlane:INFO] - [model_managers.Token] Successfully created token: DAPP-1649
# 2023-05-03 06:57:05,609 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 5
# 2023-05-03 06:57:05,802 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/DAPP-1649
# 2023-05-03 06:57:07,993 [fastlane:INFO] - [model_managers.Token] Successfully created token: BORING-92CA
# 2023-05-03 06:57:08,445 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 6
# 2023-05-03 06:57:08,628 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/BORING-92CA
# 2023-05-03 06:57:10,561 [fastlane:INFO] - [model_managers.Token] Successfully created token: DDX-Ed3A
# 2023-05-03 06:57:11,010 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 7
# 2023-05-03 06:57:11,190 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/DDX-Ed3A
# 2023-05-03 06:57:13,061 [fastlane:INFO] - [model_managers.Token] Successfully created token: eRSDL-D3A6
# 2023-05-03 06:57:13,505 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 8
# 2023-05-03 06:57:13,684 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/eRSDL-D3A6
# 2023-05-03 06:57:15,641 [fastlane:INFO] - [model_managers.Token] Successfully created token: DIP-cD83
# 2023-05-03 06:57:16,082 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 9
# 2023-05-03 06:57:16,253 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/DIP-cD83
# 2023-05-03 06:57:18,371 [fastlane:INFO] - [model_managers.Token] Successfully created token: DRC-e606
# 2023-05-03 06:57:18,804 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 10
# 2023-05-03 06:57:18,981 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/DRC-e606
# 2023-05-03 06:57:22,036 [fastlane:INFO] - [model_managers.Token] Successfully created token: DUSK-A551
# 2023-05-03 06:57:22,471 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 11
# 2023-05-03 06:57:22,642 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/DUSK-A551
# 2023-05-03 06:57:24,549 [fastlane:INFO] - [model_managers.Token] Successfully created token: DXD-5521
# 2023-05-03 06:57:25,084 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 12
# 2023-05-03 06:57:25,266 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: DXD-5521/BNT-FF1C
# 2023-05-03 06:57:27,253 [fastlane:INFO] - [model_managers.Token] Successfully created token: EDEN-1559
# 2023-05-03 06:57:27,675 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 13
# 2023-05-03 06:57:27,859 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/EDEN-1559
# 2023-05-03 06:57:29,742 [fastlane:INFO] - [model_managers.Token] Successfully created token: ENJ-3B9c
# 2023-05-03 06:57:30,186 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 14
# 2023-05-03 06:57:30,376 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ENJ-3B9c
# 2023-05-03 06:57:32,469 [fastlane:INFO] - [model_managers.Token] Successfully created token: BBS-B430
# 2023-05-03 06:57:32,910 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 15
# 2023-05-03 06:57:33,093 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/BBS-B430
# 2023-05-03 06:57:35,175 [fastlane:INFO] - [model_managers.Token] Successfully created token: FARM-A14D
# 2023-05-03 06:57:35,605 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 16
# 2023-05-03 06:57:35,785 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/FARM-A14D
# 2023-05-03 06:57:37,776 [fastlane:INFO] - [model_managers.Token] Successfully created token: BMI-E688
# 2023-05-03 06:57:38,223 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 17
# 2023-05-03 06:57:38,399 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/BMI-E688
# 2023-05-03 06:57:40,282 [fastlane:INFO] - [model_managers.Token] Successfully created token: ANKR-EDD4
# 2023-05-03 06:57:40,705 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 18
# 2023-05-03 06:57:40,881 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ANKR-EDD4
# 2023-05-03 06:57:42,862 [fastlane:INFO] - [model_managers.Token] Successfully created token: bBADGER-fC28
# 2023-05-03 06:57:43,299 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 19
# 2023-05-03 06:57:43,492 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/bBADGER-fC28
# 2023-05-03 06:57:45,486 [fastlane:INFO] - [model_managers.Token] Successfully created token: ALCX-c8DF
# 2023-05-03 06:57:45,915 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 20
# 2023-05-03 06:57:46,089 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ALCX-c8DF
# 2023-05-03 06:57:48,066 [fastlane:INFO] - [model_managers.Token] Successfully created token: FRM-A68C
# 2023-05-03 06:57:48,513 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 21
# 2023-05-03 06:57:48,696 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/FRM-A68C
# 2023-05-03 06:57:49,777 [fastlane:INFO] - [model_managers.Token] Successfully created token: ETH-EEeE
# 2023-05-03 06:57:50,222 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 22
# 2023-05-03 06:57:50,409 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ETH-EEeE
# 2023-05-03 06:57:52,471 [fastlane:INFO] - [model_managers.Token] Successfully created token: DAI-1d0F
# 2023-05-03 06:57:52,903 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 23
# 2023-05-03 06:57:53,084 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/DAI-1d0F
# 2023-05-03 06:57:55,427 [fastlane:INFO] - [model_managers.Token] Successfully created token: LINK-86CA
# 2023-05-03 06:57:55,961 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 24
# 2023-05-03 06:57:56,133 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: LINK-86CA/BNT-FF1C
# 2023-05-03 06:57:58,403 [fastlane:INFO] - [model_managers.Token] Successfully created token: 1INCH-C302
# 2023-05-03 06:57:58,843 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 25
# 2023-05-03 06:57:59,018 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/1INCH-C302
# 2023-05-03 06:58:00,998 [fastlane:INFO] - [model_managers.Token] Successfully created token: AAVE-DaE9
# 2023-05-03 06:58:01,570 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 26
# 2023-05-03 06:58:01,761 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: AAVE-DaE9/BNT-FF1C
# 2023-05-03 06:58:03,885 [fastlane:INFO] - [model_managers.Token] Successfully created token: ALEPH-F628
# 2023-05-03 06:58:04,438 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 27
# 2023-05-03 06:58:04,628 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: ALEPH-F628/BNT-FF1C
# 2023-05-03 06:58:06,728 [fastlane:INFO] - [model_managers.Token] Successfully created token: BAT-87EF
# 2023-05-03 06:58:07,218 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 28
# 2023-05-03 06:58:07,403 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/BAT-87EF
# 2023-05-03 06:58:09,490 [fastlane:INFO] - [model_managers.Token] Successfully created token: ALPHA-0975
# 2023-05-03 06:58:09,944 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 29
# 2023-05-03 06:58:10,124 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ALPHA-0975
# 2023-05-03 06:58:12,039 [fastlane:INFO] - [model_managers.Token] Successfully created token: AMP-95C2
# 2023-05-03 06:58:12,497 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 30
# 2023-05-03 06:58:12,686 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/AMP-95C2
# 2023-05-03 06:58:14,701 [fastlane:INFO] - [model_managers.Token] Successfully created token: ANT-88C0
# 2023-05-03 06:58:15,166 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 31
# 2023-05-03 06:58:15,349 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ANT-88C0
# 2023-05-03 06:58:17,436 [fastlane:INFO] - [model_managers.Token] Successfully created token: APW-60c8
# 2023-05-03 06:58:17,904 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 32
# 2023-05-03 06:58:18,094 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/APW-60c8
# 2023-05-03 06:58:20,240 [fastlane:INFO] - [model_managers.Token] Successfully created token: ARCONA-52B3
# 2023-05-03 06:58:20,689 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 33
# 2023-05-03 06:58:20,905 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ARCONA-52B3
# 2023-05-03 06:58:22,986 [fastlane:INFO] - [model_managers.Token] Successfully created token: AUC-5663
# 2023-05-03 06:58:23,448 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 34
# 2023-05-03 06:58:23,640 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/AUC-5663
# 2023-05-03 06:58:25,815 [fastlane:INFO] - [model_managers.Token] Successfully created token: FODL-b9C3
# 2023-05-03 06:58:26,268 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 35
# 2023-05-03 06:58:26,453 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/FODL-b9C3
# 2023-05-03 06:58:28,499 [fastlane:INFO] - [model_managers.Token] Successfully created token: PHTR-22dA
# 2023-05-03 06:58:29,043 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 36
# 2023-05-03 06:58:29,228 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: PHTR-22dA/BNT-FF1C
# 2023-05-03 06:58:31,412 [fastlane:INFO] - [model_managers.Token] Successfully created token: GNO-6b96
# 2023-05-03 06:58:31,882 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 37
# 2023-05-03 06:58:32,067 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/GNO-6b96
# 2023-05-03 06:58:34,152 [fastlane:INFO] - [model_managers.Token] Successfully created token: GRT-44a7
# 2023-05-03 06:58:34,612 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 38
# 2023-05-03 06:58:34,795 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/GRT-44a7
# 2023-05-03 06:58:36,799 [fastlane:INFO] - [model_managers.Token] Successfully created token: rETH-6393
# 2023-05-03 06:58:37,264 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 39
# 2023-05-03 06:58:37,450 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/rETH-6393
# 2023-05-03 06:58:39,497 [fastlane:INFO] - [model_managers.Token] Successfully created token: RLC-7375
# 2023-05-03 06:58:39,957 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 40
# 2023-05-03 06:58:40,155 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/RLC-7375
# 2023-05-03 06:58:42,164 [fastlane:INFO] - [model_managers.Token] Successfully created token: ROOK-3d4a
# 2023-05-03 06:58:42,608 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 41
# 2023-05-03 06:58:42,793 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ROOK-3d4a
# 2023-05-03 06:58:44,737 [fastlane:INFO] - [model_managers.Token] Successfully created token: RPL-A51f
# 2023-05-03 06:58:45,188 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 42
# 2023-05-03 06:58:45,375 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/RPL-A51f
# 2023-05-03 06:58:47,329 [fastlane:INFO] - [model_managers.Token] Successfully created token: RUNE-49cb
# 2023-05-03 06:58:47,777 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 43
# 2023-05-03 06:58:47,965 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/RUNE-49cb
# 2023-05-03 06:58:49,976 [fastlane:INFO] - [model_managers.Token] Successfully created token: SFI-902c
# 2023-05-03 06:58:50,428 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 44
# 2023-05-03 06:58:50,617 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/SFI-902c
# 2023-05-03 06:58:52,929 [fastlane:INFO] - [model_managers.Token] Successfully created token: SHEESHA-E768
# 2023-05-03 06:58:53,383 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 45
# 2023-05-03 06:58:53,566 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/SHEESHA-E768
# 2023-05-03 06:58:55,854 [fastlane:INFO] - [model_managers.Token] Successfully created token: SNX-2a6F
# 2023-05-03 06:58:56,416 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 46
# 2023-05-03 06:58:56,596 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: SNX-2a6F/BNT-FF1C
# 2023-05-03 06:58:59,012 [fastlane:INFO] - [model_managers.Token] Successfully created token: TEMP-1aB9
# 2023-05-03 06:58:59,451 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 47
# 2023-05-03 06:58:59,632 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/TEMP-1aB9
# 2023-05-03 06:59:01,534 [fastlane:INFO] - [model_managers.Token] Successfully created token: TRAC-0A6F
# 2023-05-03 06:59:01,986 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 48
# 2023-05-03 06:59:02,178 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/TRAC-0A6F
# 2023-05-03 06:59:04,116 [fastlane:INFO] - [model_managers.Token] Successfully created token: UNI-F984
# 2023-05-03 06:59:04,663 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 49
# 2023-05-03 06:59:04,844 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: UNI-F984/BNT-FF1C
# 2023-05-03 06:59:07,012 [fastlane:INFO] - [model_managers.Token] Successfully created token: UOS-5C8c
# 2023-05-03 06:59:07,472 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 50
# 2023-05-03 06:59:07,653 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/UOS-5C8c
# 2023-05-03 06:59:09,654 [fastlane:INFO] - [model_managers.Token] Successfully created token: USDC-eB48
# 2023-05-03 06:59:10,202 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 51
# 2023-05-03 06:59:10,383 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: USDC-eB48/BNT-FF1C
# 2023-05-03 06:59:12,638 [fastlane:INFO] - [model_managers.Token] Successfully created token: vBNT-7f94
# 2023-05-03 06:59:13,095 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 52
# 2023-05-03 06:59:13,279 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/vBNT-7f94
# 2023-05-03 06:59:15,294 [fastlane:INFO] - [model_managers.Token] Successfully created token: VITA-A321
# 2023-05-03 06:59:15,751 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 53
# 2023-05-03 06:59:15,937 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/VITA-A321
# 2023-05-03 06:59:18,040 [fastlane:INFO] - [model_managers.Token] Successfully created token: VLX-Edb9
# 2023-05-03 06:59:18,492 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 54
# 2023-05-03 06:59:18,683 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/VLX-Edb9
# 2023-05-03 06:59:20,743 [fastlane:INFO] - [model_managers.Token] Successfully created token: WBTC-C599
# 2023-05-03 06:59:21,206 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 55
# 2023-05-03 06:59:21,393 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/WBTC-C599
# 2023-05-03 06:59:23,245 [fastlane:INFO] - [model_managers.Token] Successfully created token: wNXM-2bDE
# 2023-05-03 06:59:23,804 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 56
# 2023-05-03 06:59:23,988 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: wNXM-2bDE/BNT-FF1C
# 2023-05-03 06:59:26,003 [fastlane:INFO] - [model_managers.Token] Successfully created token: WOO-5D4B
# 2023-05-03 06:59:26,477 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 57
# 2023-05-03 06:59:26,664 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/WOO-5D4B
# 2023-05-03 06:59:28,740 [fastlane:INFO] - [model_managers.Token] Successfully created token: wstETH-2Ca0
# 2023-05-03 06:59:29,204 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 58
# 2023-05-03 06:59:29,386 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/wstETH-2Ca0
# 2023-05-03 06:59:31,659 [fastlane:INFO] - [model_managers.Token] Successfully created token: WXT-E915
# 2023-05-03 06:59:32,118 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 59
# 2023-05-03 06:59:32,301 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/WXT-E915
# 2023-05-03 06:59:34,368 [fastlane:INFO] - [model_managers.Token] Successfully created token: YFI-d93e
# 2023-05-03 06:59:34,915 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 60
# 2023-05-03 06:59:35,095 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: YFI-d93e/BNT-FF1C
# 2023-05-03 06:59:37,205 [fastlane:INFO] - [model_managers.Token] Successfully created token: ZCN-3B78
# 2023-05-03 06:59:37,672 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 61
# 2023-05-03 06:59:37,859 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ZCN-3B78
# 2023-05-03 06:59:40,092 [fastlane:INFO] - [model_managers.Token] Successfully created token: ZRX-F498
# 2023-05-03 06:59:40,630 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 62
# 2023-05-03 06:59:40,818 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: ZRX-F498/BNT-FF1C
# 2023-05-03 06:59:42,825 [fastlane:INFO] - [model_managers.Token] Successfully created token: LYRA-05Bf
# 2023-05-03 06:59:43,285 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 63
# 2023-05-03 06:59:43,468 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/LYRA-05Bf
# 2023-05-03 06:59:45,607 [fastlane:INFO] - [model_managers.Token] Successfully created token: OCEAN-9F48
# 2023-05-03 06:59:46,153 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 64
# 2023-05-03 06:59:46,339 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: OCEAN-9F48/BNT-FF1C
# 2023-05-03 06:59:48,339 [fastlane:INFO] - [model_managers.Token] Successfully created token: USDT-1ec7
# 2023-05-03 06:59:48,784 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 65
# 2023-05-03 06:59:48,975 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/USDT-1ec7
# 2023-05-03 06:59:50,980 [fastlane:INFO] - [model_managers.Token] Successfully created token: REQ-938a
# 2023-05-03 06:59:51,426 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 66
# 2023-05-03 06:59:51,615 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/REQ-938a
# 2023-05-03 06:59:53,700 [fastlane:INFO] - [model_managers.Token] Successfully created token: renBTC-B27D
# 2023-05-03 06:59:54,258 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 67
# 2023-05-03 06:59:54,443 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: renBTC-B27D/BNT-FF1C
# 2023-05-03 06:59:56,501 [fastlane:INFO] - [model_managers.Token] Successfully created token: REN-2a38
# 2023-05-03 06:59:57,045 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 68
# 2023-05-03 06:59:57,220 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: REN-2a38/BNT-FF1C
# 2023-05-03 06:59:59,610 [fastlane:INFO] - [model_managers.Token] Successfully created token: MFI-355B
# 2023-05-03 07:00:00,056 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 69
# 2023-05-03 07:00:00,238 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/MFI-355B
# 2023-05-03 07:00:02,263 [fastlane:INFO] - [model_managers.Token] Successfully created token: GTC-163F
# 2023-05-03 07:00:02,714 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 70
# 2023-05-03 07:00:03,010 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/GTC-163F
# 2023-05-03 07:00:05,091 [fastlane:INFO] - [model_managers.Token] Successfully created token: HEGIC-8430
# 2023-05-03 07:00:05,551 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 71
# 2023-05-03 07:00:05,730 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/HEGIC-8430
# 2023-05-03 07:00:07,895 [fastlane:INFO] - [model_managers.Token] Successfully created token: ICHI-A881
# 2023-05-03 07:00:08,348 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 72
# 2023-05-03 07:00:08,536 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/ICHI-A881
# 2023-05-03 07:00:10,844 [fastlane:INFO] - [model_managers.Token] Successfully created token: IDLE-D39e
# 2023-05-03 07:00:11,304 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 73
# 2023-05-03 07:00:11,486 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/IDLE-D39e
# 2023-05-03 07:00:14,077 [fastlane:INFO] - [model_managers.Token] Successfully created token: INDEX-4cab
# 2023-05-03 07:00:14,516 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 74
# 2023-05-03 07:00:14,691 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/INDEX-4cab
# 2023-05-03 07:00:16,780 [fastlane:INFO] - [model_managers.Token] Successfully created token: KNC-D200
# 2023-05-03 07:00:17,231 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 75
# 2023-05-03 07:00:17,406 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/KNC-D200
# 2023-05-03 07:00:19,779 [fastlane:INFO] - [model_managers.Token] Successfully created token: KTN-FC1C
# 2023-05-03 07:00:20,224 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 76
# 2023-05-03 07:00:20,406 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/KTN-FC1C
# 2023-05-03 07:00:22,468 [fastlane:INFO] - [model_managers.Token] Successfully created token: LPL-75B8
# 2023-05-03 07:00:22,898 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 77
# 2023-05-03 07:00:23,079 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/LPL-75B8
# 2023-05-03 07:00:25,534 [fastlane:INFO] - [model_managers.Token] Successfully created token: LRC-EafD
# 2023-05-03 07:00:26,080 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 78
# 2023-05-03 07:00:26,260 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: LRC-EafD/BNT-FF1C
# 2023-05-03 07:00:28,396 [fastlane:INFO] - [model_managers.Token] Successfully created token: MANA-C942
# 2023-05-03 07:00:28,837 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 79
# 2023-05-03 07:00:29,020 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/MANA-C942
# 2023-05-03 07:00:31,595 [fastlane:INFO] - [model_managers.Token] Successfully created token: MASK-3074
# 2023-05-03 07:00:32,023 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 80
# 2023-05-03 07:00:32,197 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/MASK-3074
# 2023-05-03 07:00:34,304 [fastlane:INFO] - [model_managers.Token] Successfully created token: MATIC-eBB0
# 2023-05-03 07:00:34,826 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 81
# 2023-05-03 07:00:34,996 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: MATIC-eBB0/BNT-FF1C
# 2023-05-03 07:00:36,339 [fastlane:INFO] - [model_managers.Token] Successfully created token: MKR-79A2
# 2023-05-03 07:00:36,779 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 82
# 2023-05-03 07:00:36,957 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/MKR-79A2
# 2023-05-03 07:00:39,025 [fastlane:INFO] - [model_managers.Token] Successfully created token: RARI-41CF
# 2023-05-03 07:00:39,546 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 83
# 2023-05-03 07:00:39,726 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: RARI-41CF/BNT-FF1C
# 2023-05-03 07:00:41,943 [fastlane:INFO] - [model_managers.Token] Successfully created token: MLN-1892
# 2023-05-03 07:00:42,466 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 84
# 2023-05-03 07:00:42,640 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: MLN-1892/BNT-FF1C
# 2023-05-03 07:00:44,706 [fastlane:INFO] - [model_managers.Token] Successfully created token: MONA-412A
# 2023-05-03 07:00:45,140 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 85
# 2023-05-03 07:00:45,318 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/MONA-412A
# 2023-05-03 07:00:47,293 [fastlane:INFO] - [model_managers.Token] Successfully created token: MPH-35C5
# 2023-05-03 07:00:47,738 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 86
# 2023-05-03 07:00:47,921 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/MPH-35C5
# 2023-05-03 07:00:50,002 [fastlane:INFO] - [model_managers.Token] Successfully created token: NDX-5F83
# 2023-05-03 07:00:50,442 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 87
# 2023-05-03 07:00:50,627 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/NDX-5F83
# 2023-05-03 07:00:52,637 [fastlane:INFO] - [model_managers.Token] Successfully created token: NEXO-5206
# 2023-05-03 07:00:53,076 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 88
# 2023-05-03 07:00:53,257 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/NEXO-5206
# 2023-05-03 07:00:55,406 [fastlane:INFO] - [model_managers.Token] Successfully created token: NMR-6671
# 2023-05-03 07:00:55,845 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 89
# 2023-05-03 07:00:56,029 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/NMR-6671
# 2023-05-03 07:00:57,987 [fastlane:INFO] - [model_managers.Token] Successfully created token: NOIA-b6ca
# 2023-05-03 07:00:58,426 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 90
# 2023-05-03 07:00:58,601 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/NOIA-b6ca
# 2023-05-03 07:01:00,623 [fastlane:INFO] - [model_managers.Token] Successfully created token: OPIUM-eC11
# 2023-05-03 07:01:01,060 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 91
# 2023-05-03 07:01:01,242 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/OPIUM-eC11
# 2023-05-03 07:01:03,289 [fastlane:INFO] - [model_managers.Token] Successfully created token: PLR-9C17
# 2023-05-03 07:01:03,728 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 92
# 2023-05-03 07:01:03,908 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/PLR-9C17
# 2023-05-03 07:01:06,035 [fastlane:INFO] - [model_managers.Token] Successfully created token: POWR-1269
# 2023-05-03 07:01:06,484 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 93
# 2023-05-03 07:01:06,658 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/POWR-1269
# 2023-05-03 07:01:08,647 [fastlane:INFO] - [model_managers.Token] Successfully created token: PSP-3dE5
# 2023-05-03 07:01:09,086 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 94
# 2023-05-03 07:01:09,267 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/PSP-3dE5
# 2023-05-03 07:01:11,424 [fastlane:INFO] - [model_managers.Token] Successfully created token: QNT-4675
# 2023-05-03 07:01:11,956 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 95
# 2023-05-03 07:01:12,136 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: QNT-4675/BNT-FF1C
# 2023-05-03 07:01:14,159 [fastlane:INFO] - [model_managers.Token] Successfully created token: DATA-8b76
# 2023-05-03 07:01:14,620 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 96
# 2023-05-03 07:01:14,802 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v2: BNT-FF1C/DATA-8b76
# 2023-05-03 07:01:16,163 [fastlane:INFO] - [model_managers.Token] Successfully created token: xSUSHI-4272
# 2023-05-03 07:01:16,612 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 97
# 2023-05-03 07:01:17,855 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/xSUSHI-4272
# 2023-05-03 07:01:19,073 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ALPHA-0975
# 2023-05-03 07:01:20,254 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ENJ-3B9c
# 2023-05-03 07:01:21,591 [fastlane:INFO] - [model_managers.Token] Successfully created token: CHZ-b4AF
# 2023-05-03 07:01:22,056 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 98
# 2023-05-03 07:01:22,766 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/CHZ-b4AF
# 2023-05-03 07:01:23,509 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 99
# 2023-05-03 07:01:24,012 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C, 'NoneType' object is not subscriptable
# 2023-05-03 07:01:24,015 [fastlane:ERROR] - Error in session_scope: 'NoneType' object has no attribute 'exchange_name'
# 2023-05-03 07:01:24,016 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0x1F573D6Fb3F13d689FF844B4cE37794d79a7FF1C on bancor_v3, 'NoneType' object has no attribute 'exchange_name', continuing...
# 2023-05-03 07:01:25,015 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/BAT-87EF
# 2023-05-03 07:01:25,756 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 100
# 2023-05-03 07:01:26,409 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/AAVE-DaE9
# 2023-05-03 07:01:27,614 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ETH-EEeE
# 2023-05-03 07:01:28,598 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/AMP-95C2
# 2023-05-03 07:01:29,570 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/DAPP-1649
# 2023-05-03 07:01:30,563 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ANKR-EDD4
# 2023-05-03 07:01:31,704 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/APW-60c8
# 2023-05-03 07:01:32,715 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ARCONA-52B3
# 2023-05-03 07:01:34,064 [fastlane:INFO] - [model_managers.Token] Successfully created token: ARMOR-E46a
# 2023-05-03 07:01:34,508 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 101
# 2023-05-03 07:01:35,141 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ARMOR-E46a
# 2023-05-03 07:01:36,132 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/AUC-5663
# 2023-05-03 07:01:37,160 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/BBS-B430
# 2023-05-03 07:01:38,153 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/BORING-92CA
# 2023-05-03 07:01:39,729 [fastlane:INFO] - [model_managers.Token] Successfully created token: ENS-9D72
# 2023-05-03 07:01:40,184 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 102
# 2023-05-03 07:01:40,927 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ENS-9D72
# 2023-05-03 07:01:41,960 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/GRT-44a7
# 2023-05-03 07:01:43,357 [fastlane:INFO] - [model_managers.Token] Successfully created token: ICHI-C4d6
# 2023-05-03 07:01:43,798 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 103
# 2023-05-03 07:01:44,351 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0x111111517e4929D3dcbdfa7CCe55d30d4B6BC4d6, 'NoneType' object is not subscriptable
# 2023-05-03 07:01:44,355 [fastlane:ERROR] - Error in session_scope: 'NoneType' object has no attribute 'exchange_name'
# 2023-05-03 07:01:44,356 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0x111111517e4929D3dcbdfa7CCe55d30d4B6BC4d6 on bancor_v3, 'NoneType' object has no attribute 'exchange_name', continuing...
# 2023-05-03 07:01:45,040 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 104
# 2023-05-03 07:01:45,685 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/LINK-86CA
# 2023-05-03 07:01:46,407 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 105
# 2023-05-03 07:01:47,072 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/YFI-d93e
# 2023-05-03 07:01:47,666 [fastlane:ERROR] - [DatabaseManager.get_or_create_token] execution reverted: execution reverted
# 2023-05-03 07:01:48,225 [fastlane:ERROR] - [DatabaseManager.get_or_create_token] execution reverted: execution reverted
# 2023-05-03 07:01:48,227 [fastlane:ERROR] - [DatabaseManager.get_or_create_pair] 'NoneType' object has no attribute 'key'
# 2023-05-03 07:01:48,359 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0x8E303D296851B320e6a697bAcB979d13c9D6E760, 'NoneType' object has no attribute 'name'
# 2023-05-03 07:01:48,362 [fastlane:ERROR] - Error in session_scope: 'NoneType' object has no attribute 'exchange_name'
# 2023-05-03 07:01:48,363 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0x8E303D296851B320e6a697bAcB979d13c9D6E760 on bancor_v3, 'NoneType' object has no attribute 'exchange_name', continuing...
# 2023-05-03 07:01:49,340 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/WBTC-C599
# 2023-05-03 07:01:50,331 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/USDT-1ec7
# 2023-05-03 07:01:51,024 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 106
# 2023-05-03 07:01:51,670 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/USDC-eB48
# 2023-05-03 07:01:52,805 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/UOS-5C8c
# 2023-05-03 07:01:53,523 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 107
# 2023-05-03 07:01:54,203 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/UNI-F984
# 2023-05-03 07:01:55,222 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/TRAC-0A6F
# 2023-05-03 07:01:55,927 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 108
# 2023-05-03 07:01:56,579 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/SNX-2a6F
# 2023-05-03 07:01:57,682 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/RPL-A51f
# 2023-05-03 07:01:58,379 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 109
# 2023-05-03 07:01:59,091 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/QNT-4675
# 2023-05-03 07:01:59,796 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 110
# 2023-05-03 07:02:00,437 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/OCEAN-9F48
# 2023-05-03 07:02:01,418 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/MKR-79A2
# 2023-05-03 07:02:02,128 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 111
# 2023-05-03 07:02:02,764 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/MATIC-eBB0
# 2023-05-03 07:02:03,763 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/MANA-C942
# 2023-05-03 07:02:04,484 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 112
# 2023-05-03 07:02:05,191 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/COMP-6888
# 2023-05-03 07:02:06,212 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/DAI-1d0F
# 2023-05-03 07:02:07,269 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/DIP-cD83
# 2023-05-03 07:02:08,606 [fastlane:INFO] - [model_managers.Token] Successfully created token: UMA-F828
# 2023-05-03 07:02:09,042 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 113
# 2023-05-03 07:02:09,809 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/UMA-F828
# 2023-05-03 07:02:10,916 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/REQ-938a
# 2023-05-03 07:02:11,917 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/RLC-7375
# 2023-05-03 07:02:13,238 [fastlane:INFO] - [model_managers.Token] Successfully created token: RNB-e743
# 2023-05-03 07:02:13,688 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 114
# 2023-05-03 07:02:14,325 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/RNB-e743
# 2023-05-03 07:02:15,351 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ROOK-3d4a
# 2023-05-03 07:02:16,689 [fastlane:INFO] - [model_managers.Token] Successfully created token: SATA-bEe1
# 2023-05-03 07:02:17,122 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 115
# 2023-05-03 07:02:17,878 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/SATA-bEe1
# 2023-05-03 07:02:18,865 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/SHEESHA-E768
# 2023-05-03 07:02:19,929 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/TEMP-1aB9
# 2023-05-03 07:02:21,062 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/vBNT-7f94
# 2023-05-03 07:02:21,764 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 116
# 2023-05-03 07:02:22,441 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/RARI-41CF
# 2023-05-03 07:02:23,147 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 117
# 2023-05-03 07:02:23,804 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/wNXM-2bDE
# 2023-05-03 07:02:24,804 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/WOO-5D4B
# 2023-05-03 07:02:25,816 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/wstETH-2Ca0
# 2023-05-03 07:02:27,161 [fastlane:INFO] - [model_managers.Token] Successfully created token: ACRE-FC21
# 2023-05-03 07:02:27,609 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 118
# 2023-05-03 07:02:28,354 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ACRE-FC21
# 2023-05-03 07:02:29,967 [fastlane:INFO] - [model_managers.Token] Successfully created token: CROWN-E0fa
# 2023-05-03 07:02:30,402 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 119
# 2023-05-03 07:02:31,195 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/CROWN-E0fa
# 2023-05-03 07:02:32,229 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/EDEN-1559
# 2023-05-03 07:02:33,353 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ZCN-3B78
# 2023-05-03 07:02:34,063 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 120
# 2023-05-03 07:02:34,790 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/REN-2a38
# 2023-05-03 07:02:36,078 [fastlane:INFO] - [model_managers.Token] Successfully created token: SHIBGF-65d6
# 2023-05-03 07:02:36,519 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 121
# 2023-05-03 07:02:37,215 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/SHIBGF-65d6
# 2023-05-03 07:02:37,921 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 122
# 2023-05-03 07:02:38,553 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/PHTR-22dA
# 2023-05-03 07:02:39,564 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/LPL-75B8
# 2023-05-03 07:02:40,918 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/OPIUM-eC11
# 2023-05-03 07:02:42,103 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/eRSDL-D3A6
# 2023-05-03 07:02:43,154 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/HEGIC-8430
# 2023-05-03 07:02:44,489 [fastlane:INFO] - [model_managers.Token] Successfully created token: HOT-26E2
# 2023-05-03 07:02:44,934 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 123
# 2023-05-03 07:02:45,579 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/HOT-26E2
# 2023-05-03 07:02:46,615 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/ICHI-A881
# 2023-05-03 07:02:47,667 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/IDLE-D39e
# 2023-05-03 07:02:48,682 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/KTN-FC1C
# 2023-05-03 07:02:49,888 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/INDEX-4cab
# 2023-05-03 07:02:50,591 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 124
# 2023-05-03 07:02:51,365 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/LRC-EafD
# 2023-05-03 07:02:52,812 [fastlane:INFO] - [model_managers.Token] Successfully created token: MFG-0312
# 2023-05-03 07:02:53,247 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 125
# 2023-05-03 07:02:53,920 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/MFG-0312
# 2023-05-03 07:02:54,922 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/MONA-412A
# 2023-05-03 07:02:55,905 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/MPH-35C5
# 2023-05-03 07:02:56,914 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/NDX-5F83
# 2023-05-03 07:02:58,028 [fastlane:INFO] - [model_managers.Pool] Created pool on bancor_v3: BNT-FF1C/NMR-6671
# 2023-05-03 07:03:00,381 [fastlane:INFO] - [model_managers.Token] Successfully created token: WETH-6Cc2
# 2023-05-03 07:03:01,560 [fastlane:INFO] - [model_managers.Token] Successfully created token: DONUT-54A9
# 2023-05-03 07:03:02,005 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 126
# 2023-05-03 07:03:02,186 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: WETH-6Cc2/DONUT-54A9
# 2023-05-03 07:03:04,544 [fastlane:INFO] - [model_managers.Token] Successfully created token: JIG-49E9
# 2023-05-03 07:03:04,975 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 127
# 2023-05-03 07:03:05,161 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: WETH-6Cc2/JIG-49E9
# 2023-05-03 07:03:07,514 [fastlane:INFO] - [model_managers.Token] Successfully created token: OCTO-2BA3
# 2023-05-03 07:03:08,075 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 128
# 2023-05-03 07:03:08,255 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: OCTO-2BA3/USDC-eB48
# 2023-05-03 07:03:10,364 [fastlane:INFO] - [model_managers.Token] Successfully created token: ECO-5727
# 2023-05-03 07:03:10,900 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 129
# 2023-05-03 07:03:11,079 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: ECO-5727/USDC-eB48
# 2023-05-03 07:03:13,381 [fastlane:INFO] - [model_managers.Token] Successfully created token: SAT-1332
# 2023-05-03 07:03:13,847 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 130
# 2023-05-03 07:03:14,031 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: WETH-6Cc2/SAT-1332
# 2023-05-03 07:03:16,374 [fastlane:INFO] - [model_managers.Token] Successfully created token: MIKAWA-6A26
# 2023-05-03 07:03:16,896 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 131
# 2023-05-03 07:03:17,085 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: MIKAWA-6A26/WETH-6Cc2
# 2023-05-03 07:03:18,908 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 132
# 2023-05-03 07:03:19,090 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: ANKR-EDD4/WETH-6Cc2
# 2023-05-03 07:03:21,567 [fastlane:INFO] - [model_managers.Token] Successfully created token: DIGG-01C3
# 2023-05-03 07:03:21,997 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 133
# 2023-05-03 07:03:22,185 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: WBTC-C599/DIGG-01C3
# 2023-05-03 07:03:24,369 [fastlane:INFO] - [model_managers.Token] Successfully created token: MOON-4824
# 2023-05-03 07:03:24,911 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 134
# 2023-05-03 07:03:25,091 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: MOON-4824/WETH-6Cc2
# 2023-05-03 07:03:27,614 [fastlane:INFO] - [model_managers.Token] Successfully created token: SHFT-6d19
# 2023-05-03 07:03:28,054 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 135
# 2023-05-03 07:03:28,237 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: WETH-6Cc2/SHFT-6d19
# 2023-05-03 07:03:30,830 [fastlane:INFO] - [model_managers.Token] Successfully created token: BTE-80Ef
# 2023-05-03 07:03:31,360 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 136
# 2023-05-03 07:03:31,541 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: BTE-80Ef/WETH-6Cc2
# 2023-05-03 07:03:34,067 [fastlane:INFO] - [model_managers.Token] Successfully created token: DFP2-8E6D
# 2023-05-03 07:03:34,597 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 137
# 2023-05-03 07:03:34,781 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: DFP2-8E6D/WETH-6Cc2
# 2023-05-03 07:03:37,354 [fastlane:INFO] - [model_managers.Token] Successfully created token: SPIRAL-1C3c
# 2023-05-03 07:03:37,872 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 138
# 2023-05-03 07:03:38,052 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: SPIRAL-1C3c/USDC-eB48
# 2023-05-03 07:03:40,509 [fastlane:INFO] - [model_managers.Token] Successfully created token: REVV-A8Ca
# 2023-05-03 07:03:41,746 [fastlane:INFO] - [model_managers.Token] Successfully created token: GMEE-2373
# 2023-05-03 07:03:42,192 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 139
# 2023-05-03 07:03:42,371 [fastlane:INFO] - [model_managers.Pool] Created pool on uniswap_v2: REVV-A8Ca/GMEE-2373
# ...
# 2023-05-03 07:17:25,492 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 390
# 2023-05-03 07:17:25,674 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: ARMOR-E46a/DAI-1d0F
# 2023-05-03 07:17:27,432 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 391
# 2023-05-03 07:17:27,604 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: ARMOR-E46a/WBTC-C599
# 2023-05-03 07:17:29,374 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 392
# 2023-05-03 07:17:29,550 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: MANA-C942/WETH-6Cc2
# 2023-05-03 07:17:31,166 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: USDC-eB48/WETH-6Cc2
# 2023-05-03 07:17:32,868 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 393
# 2023-05-03 07:17:33,042 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: MASK-3074/WETH-6Cc2
# 2023-05-03 07:17:34,860 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 394
# 2023-05-03 07:17:35,036 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: wNXM-2bDE/WETH-6Cc2
# 2023-05-03 07:17:36,821 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 395
# 2023-05-03 07:17:36,997 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: WBTC-C599/WETH-6Cc2
# 2023-05-03 07:17:38,505 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: USDC-eB48/USDT-1ec7
# 2023-05-03 07:17:40,190 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 396
# 2023-05-03 07:17:40,370 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: USDC-eB48/UOS-5C8c
# 2023-05-03 07:17:42,152 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 397
# 2023-05-03 07:17:42,333 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: UNI-F984/DAI-1d0F
# 2023-05-03 07:17:44,063 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 398
# 2023-05-03 07:17:44,243 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: UNI-F984/USDT-1ec7
# 2023-05-03 07:17:45,959 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 399
# 2023-05-03 07:17:46,136 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: UNI-F984/WETH-6Cc2
# 2023-05-03 07:17:47,809 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 400
# 2023-05-03 07:17:47,992 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: UMA-F828/WETH-6Cc2
# 2023-05-03 07:17:50,435 [fastlane:INFO] - [model_managers.Token] Successfully created token: TRU-3784
# 2023-05-03 07:17:50,972 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 401
# 2023-05-03 07:17:51,151 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: TRU-3784/WETH-6Cc2
# 2023-05-03 07:17:52,965 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 402
# 2023-05-03 07:17:53,164 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: TRAC-0A6F/WETH-6Cc2
# 2023-05-03 07:17:54,955 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 403
# 2023-05-03 07:17:55,130 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: DAI-1d0F/SUSHI-0fE2
# 2023-05-03 07:17:56,945 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 404
# 2023-05-03 07:17:57,123 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: SUSHI-0fE2/USDT-1ec7
# 2023-05-03 07:17:58,909 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 405
# 2023-05-03 07:17:59,087 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: SUSHI-0fE2/USDC-eB48
# 2023-05-03 07:18:00,763 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 406
# 2023-05-03 07:18:00,938 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: SUSHI-0fE2/WETH-6Cc2
# 2023-05-03 07:18:03,257 [fastlane:INFO] - [model_managers.Token] Successfully created token: STAKE-95e6
# 2023-05-03 07:18:03,766 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 407
# 2023-05-03 07:18:03,932 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: STAKE-95e6/WETH-6Cc2
# 2023-05-03 07:18:05,705 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 408
# 2023-05-03 07:18:05,885 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: SNX-2a6F/USDT-1ec7
# 2023-05-03 07:18:07,640 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 409
# 2023-05-03 07:18:07,816 [fastlane:INFO] - [model_managers.Pool] Created pool on sushiswap_v2: USDC-eB48/SNX-2a6F
# 2023-05-03 07:18:32,621 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 410
# 2023-05-03 07:18:32,803 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/DAI-1d0F
# 2023-05-03 07:18:33,332 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/DAI-1d0F
# 2023-05-03 07:18:34,798 [fastlane:INFO] - [model_managers.Token] Successfully created token: stETH-fE84
# 2023-05-03 07:18:35,230 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 411
# 2023-05-03 07:18:35,410 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/stETH-fE84
# 2023-05-03 07:18:36,135 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 412
# 2023-05-03 07:18:36,321 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: stETH-fE84/ETH-EEeE
# 2023-05-03 07:18:36,860 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: USDC-eB48/USDT-1ec7
# 2023-05-03 07:18:37,395 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: USDC-eB48/USDT-1ec7
# 2023-05-03 07:18:38,110 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 413
# 2023-05-03 07:18:38,288 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: USDC-eB48/DAI-1d0F
# 2023-05-03 07:18:38,979 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 414
# 2023-05-03 07:18:39,151 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:39,689 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:40,212 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:40,730 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:41,240 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:41,767 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:42,296 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:42,821 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:43,343 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:43,866 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:44,392 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:44,911 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:45,429 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:45,953 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDC-eB48
# 2023-05-03 07:18:46,482 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: DAI-1d0F/USDT-1ec7
# 2023-05-03 07:18:47,023 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: USDC-eB48/BNT-FF1C
# 2023-05-03 07:18:47,549 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: BNT-FF1C/USDC-eB48
# 2023-05-03 07:18:48,237 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 415
# 2023-05-03 07:18:48,410 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDT-1ec7
# 2023-05-03 07:18:48,940 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/USDT-1ec7
# 2023-05-03 07:18:49,651 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 416
# 2023-05-03 07:18:49,829 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: rETH-6393/ETH-EEeE
# 2023-05-03 07:18:51,015 [fastlane:INFO] - [model_managers.Token] Successfully created token: PEPE-1933
# 2023-05-03 07:18:51,545 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 417
# 2023-05-03 07:18:51,732 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: PEPE-1933/USDC-eB48
# 2023-05-03 07:18:52,445 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 418
# 2023-05-03 07:18:52,630 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/BNT-FF1C
# 2023-05-03 07:18:53,149 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: BNT-FF1C/ETH-EEeE
# 2023-05-03 07:18:53,705 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: BNT-FF1C/ETH-EEeE
# 2023-05-03 07:18:54,215 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: BNT-FF1C/ETH-EEeE
# 2023-05-03 07:18:54,747 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: BNT-FF1C/ETH-EEeE
# 2023-05-03 07:18:55,484 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 419
# 2023-05-03 07:18:55,665 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: WBTC-C599/USDC-eB48
# 2023-05-03 07:18:56,175 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: WBTC-C599/USDC-eB48
# 2023-05-03 07:18:56,694 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: BNT-FF1C/vBNT-7f94
# 2023-05-03 07:18:57,380 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 420
# 2023-05-03 07:18:57,558 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: vBNT-7f94/BNT-FF1C
# 2023-05-03 07:18:58,084 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: vBNT-7f94/BNT-FF1C
# 2023-05-03 07:18:58,617 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: vBNT-7f94/BNT-FF1C
# 2023-05-03 07:18:59,137 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: vBNT-7f94/BNT-FF1C
# 2023-05-03 07:18:59,679 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: vBNT-7f94/BNT-FF1C
# 2023-05-03 07:19:00,225 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: LINK-86CA/USDT-1ec7
# 2023-05-03 07:19:00,906 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 421
# 2023-05-03 07:19:01,087 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: vBNT-7f94/USDC-eB48
# 2023-05-03 07:19:01,612 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: vBNT-7f94/USDC-eB48
# 2023-05-03 07:19:02,926 [fastlane:INFO] - [model_managers.Token] Successfully created token: XCHF-fc08
# 2023-05-03 07:19:03,363 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 422
# 2023-05-03 07:19:03,549 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: RPL-A51f/XCHF-fc08
# 2023-05-03 07:19:04,885 [fastlane:INFO] - [model_managers.Token] Successfully created token: ARB-4ad1
# 2023-05-03 07:19:05,326 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 423
# 2023-05-03 07:19:05,505 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: MATIC-eBB0/ARB-4ad1
# 2023-05-03 07:19:06,839 [fastlane:INFO] - [model_managers.Token] Successfully created token: TSUKA-69eD
# 2023-05-03 07:19:07,368 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 424
# 2023-05-03 07:19:07,545 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: TSUKA-69eD/USDC-eB48
# 2023-05-03 07:19:09,518 [fastlane:INFO] - [model_managers.Token] Successfully created token: LBR-aCcA
# 2023-05-03 07:19:10,059 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 425
# 2023-05-03 07:19:10,242 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: LBR-aCcA/ETH-EEeE
# 2023-05-03 07:19:10,939 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 426
# 2023-05-03 07:19:11,118 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: PEPE-1933/ETH-EEeE
# 2023-05-03 07:19:11,640 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: PEPE-1933/ETH-EEeE
# 2023-05-03 07:19:12,154 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: PEPE-1933/ETH-EEeE
# 2023-05-03 07:19:13,473 [fastlane:INFO] - [model_managers.Token] Successfully created token: LYXe-be6D
# 2023-05-03 07:19:13,993 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 427
# 2023-05-03 07:19:14,164 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: LYXe-be6D/USDC-eB48
# 2023-05-03 07:19:15,367 [fastlane:INFO] - [model_managers.Token] Successfully created token: HRP-12Bf
# 2023-05-03 07:19:15,887 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 428
# 2023-05-03 07:19:16,059 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: HRP-12Bf/ETH-EEeE
# 2023-05-03 07:19:17,277 [fastlane:INFO] - [model_managers.Token] Successfully created token: Silo-B1f8
# 2023-05-03 07:19:17,804 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 429
# 2023-05-03 07:19:17,981 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: Silo-B1f8/USDC-eB48
# 2023-05-03 07:19:18,512 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: LINK-86CA/USDC-eB48
# 2023-05-03 07:19:19,200 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 430
# 2023-05-03 07:19:19,381 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: ETH-EEeE/WBTC-C599
# 2023-05-03 07:19:20,111 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 431
# 2023-05-03 07:19:20,284 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: WBTC-C599/USDT-1ec7
# 2023-05-03 07:19:21,875 [fastlane:INFO] - [model_managers.Token] Successfully created token: 0x0-1AD5
# 2023-05-03 07:19:22,406 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 432
# 2023-05-03 07:19:22,589 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: 0x0-1AD5/ETH-EEeE
# 2023-05-03 07:19:23,875 [fastlane:INFO] - [model_managers.Token] Successfully created token: SMT-7173
# 2023-05-03 07:19:24,403 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 433
# 2023-05-03 07:19:24,578 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: SMT-7173/ETH-EEeE
# 2023-05-03 07:19:25,898 [fastlane:INFO] - [model_managers.Token] Successfully created token: pepecoin-489A
# 2023-05-03 07:19:26,427 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 434
# 2023-05-03 07:19:26,611 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: pepecoin-489A/USDC-eB48
# 2023-05-03 07:19:27,883 [fastlane:INFO] - [model_managers.Token] Successfully created token: JAY-CA6E
# 2023-05-03 07:19:28,416 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 435
# 2023-05-03 07:19:28,599 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: JAY-CA6E/USDC-eB48
# 2023-05-03 07:19:29,118 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: JAY-CA6E/USDC-eB48
# 2023-05-03 07:19:29,633 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: JAY-CA6E/USDC-eB48
# 2023-05-03 07:19:30,938 [fastlane:INFO] - [model_managers.Token] Successfully created token: WYD-8991
# 2023-05-03 07:19:31,460 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 436
# 2023-05-03 07:19:31,648 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: WYD-8991/ETH-EEeE
# 2023-05-03 07:19:32,384 [fastlane:INFO] - [model_managers.Pair] Successfully created pair: 437
# 2023-05-03 07:19:32,562 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: WETH-6Cc2/USDC-eB48
# 2023-05-03 07:19:33,091 [fastlane:INFO] - [model_managers.Pool] Created pool on carbon_v1: BNT-FF1C/DAI-1d0F

# %%
CCm = bot.get_curves()
CCc1 = CCm.byparams(exchange="carbon_v1")
CCb3 = CCm.byparams(exchange="bancor_v3")
CCu2 = CCm.byparams(exchange="uniswap_v2")
CCu3 = CCm.byparams(exchange="uniswap_v3")
exch = {c.P("exchange") for c in CCm}
b3_prices_l = [(c.pairo.tknq, c.p, c.p_convention()) for c in CCb3]
b3_prices_l[:5]
b3_prices = {r[0]:r[1] for r in b3_prices_l}
u2_prices_l = [(c.pairo.pair, c.p, c.p_convention()) for c in CCu2]
price = lambda tknq, tknb: b3_prices[tknb]/b3_prices[tknq]
print("Number of curves:", len(CCm), len(CCb3), len(CCu2), len(CCc1), len(CCu3))
print("Number of tokens:", len(CCm.tokens()))
# for pair in [(T.WBTC, T.USDC), (T.DAI, T.USDC)]:
#     print(f"Price {pair}:", price(*pair))
print("Exchanges:", exch)
# Out:
# Number of curves: 576 71 92 117 100
# Number of tokens: 316
# Exchanges: {'carbon_v1', 'bancor_v2', 'bancor_v3', 'uniswap_v3', 'sushiswap_v2', 'uniswap_v2'}

# %%
assert {T.ETH, T.USDC, T.WBTC, T.DAI, T.BNT} - CCm.tokens() == set(), "Key tokens missing"
assert len(CCm) > 100, f"Not enough curves {len(CCm)}"
assert len(b3_prices_l) == len(CCb3)
assert price(T.WBTC, T.WBTC) == 1
assert price(T.USDC, T.USDC) == 1
assert price(T.WBTC, T.USDC) > 10000
assert price(T.USDC, T.WBTC) < 1/10000
assert np.all(r[1]>0 for r in b3_prices_l)
assert 'uniswap_v3' in exch, f"uni v3 not in exchanges {exch}"
assert 'carbon_v1' in exch, f"carbon not in exchanges {exch}"
assert len(exch) == 6, f"exchanges missing {exch}"

# %%
CCm = bot.get_curves()
len(CCm)
# Out:
# 576

# %%
#CCm.plot()

# %% [markdown]
# ### Run `_find_arbitrage_opportunities}`

# %% [markdown]
# #### AO_TOKENS

# %%
flt = [T.ETH]
r=bot._find_arbitrage_opportunities(flashloan_tokens=flt, CCm=CCm, result=bot.AO_TOKENS)
#r
len(r[0]), len(r[1]), list(r[0])[0], list(r[1])[0]
# Out:
# (316, 315, 'GRT-44a7', ('GRT-44a7', 'WETH-6Cc2'))

# %%
assert len(r[0]) > 100
assert len(r[1]) > 100
# assert r[1] == [('WETH-6Cc2', 'USDC-eB48')]

# %% [markdown]
# #### AO_CANDIDATES [USDC]

# %%
flt = [T.USDC]
r = bot._find_arbitrage_opportunities(flashloan_tokens=flt, CCm=CCm, result=bot.AO_CANDIDATES)
len(r)
# Out:
# Profit in bnt: -0.0005449002474140468873770857084 ['330', '390']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: False
# profit > best_profit: False
# contains_carbon: False
# max(netchange)<1e-4: False
# [margp_optimizer] singular Jacobian, using lstsq instead
# Profit in bnt: 42.65510997553729310993730905 ['1361129467683753853853498429727072845828-1']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: True
# profit > best_profit: True
# contains_carbon: True
# max(netchange)<1e-4: False
# Profit in bnt: 78.04946310372620104642479056 ['50', '118']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: True
# profit > best_profit: True
# contains_carbon: False
# max(netchange)<1e-4: True
# [margp_optimizer] singular Jacobian, using lstsq instead
# Profit in bnt: 31991.33248165296983245298179 ['4083388403051261561560495289181218537544-0']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: True
# profit > best_profit: True
# contains_carbon: True
# max(netchange)<1e-4: False
# Profit in bnt: -0E-49 []
# bnt_gas_limit: 319.9133248165296983245298179
# /Users/skl/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/tools/optimizer.py:1310: RuntimeWarning: divide by zero encountered in double_scalars
#   price = get(p, tokens_ix.get(tknb)) / get(p, tokens_ix.get(tknq))
# /Users/skl/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/tools/optimizer.py:1157: RuntimeWarning: invalid value encountered in subtract
#   jac[:, j] = (func(x_plus) - y) / Dxj
# /Users/skl/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/tools/optimizer.py:1371: RuntimeWarning: divide by zero encountered in log10
#   plog10 = np.log10(p)
# /Users/skl/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/tools/optimizer.py:1371: RuntimeWarning: divide by zero encountered in log10
#   plog10 = np.log10(p)
# /Users/skl/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/tools/optimizer.py:1371: RuntimeWarning: divide by zero encountered in log10
#   plog10 = np.log10(p)
# 1

# %% [markdown]
# #### AO_CANDIDATES [WETH]

# %%
flt = [T.WETH]
r = bot._find_arbitrage_opportunities(flashloan_tokens=flt, CCm=CCm, result=bot.AO_CANDIDATES)
print("---\nlen(r)", len(r))
assert len(r) >= 1, "The candidates should be populated in this direction"
r0, r1, r2, r3, r4 = r[1]
# assert r0 > 0, "The profit should be positive"
r
# Out:
# Profit in bnt: 0.07716335062677916452592271015 ['368']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: True
# profit > best_profit: True
# contains_carbon: False
# max(netchange)<1e-4: False
# Profit in bnt: 0.1874328395936049605589862038 ['173', '418']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: True
# profit > best_profit: True
# contains_carbon: False
# max(netchange)<1e-4: True
# Profit in bnt: -0.2514557051909292311760351988 ['293', '363']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: False
# profit > best_profit: False
# contains_carbon: False
# max(netchange)<1e-4: True
# Profit in bnt: -3.526228742556851983435954153E-9 ['443']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: False
# profit > best_profit: False
# contains_carbon: False
# max(netchange)<1e-4: True
# [margp_optimizer] singular Jacobian, using lstsq instead
# Profit in bnt: -0E-41 []
# bnt_gas_limit: 319.9133248165296983245298179
# [margp_optimizer] singular Jacobian, using lstsq instead
# Profit in bnt: 307.5389296688680289574527241 ['680564733841876926926749214863536422914-1']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: True
# profit > best_profit: True
# contains_carbon: True
# max(netchange)<1e-4: False
# [margp_optimizer] singular Jacobian, using lstsq instead
# Profit in bnt: -0E-41 []
# bnt_gas_limit: 319.9133248165296983245298179
# [margp_optimizer] singular Jacobian, using lstsq instead
# Profit in bnt: -10.20297238048100607539223818 ['2722258935367507707706996859454145691656-0']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: False
# profit > best_profit: False
# contains_carbon: True
# max(netchange)<1e-4: False
# Profit in bnt: 0.2666044339110980833478262759 ['346', '395']
# bnt_gas_limit: 319.9133248165296983245298179
# profit > best_profit: True
# profit > best_profit: True
# contains_carbon: False
# max(netchange)<1e-4: True
# ---
# len(r) 4
# /Users/skl/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/tools/optimizer.py:1371: RuntimeWarning: divide by zero encountered in log10
#   plog10 = np.log10(p)
# /Users/skl/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/tools/optimizer.py:1371: RuntimeWarning: divide by zero encountered in log10
#   plog10 = np.log10(p)
# [(Decimal('0.1874328395936049605589862038'),
#              WETH-6Cc2   ANKR-EDD4
#   173         0.008680 -521.855626
#   418        -0.008728  521.855619
#   AMMIn       0.008680  521.855619
#   AMMOut     -0.008728 -521.855626
#   TOTAL NET  -0.000048   -0.000007,
#   [{'cid': '173',
#     'tknin': 'WETH-6Cc2',
#     'amtin': 0.008679729140554926,
#     'tknout': 'ANKR-EDD4',
#     'amtout': -521.8556255928706,
#     'error': None},
#    {'cid': '418',
#     'tknin': 'ANKR-EDD4',
#     'amtin': 521.8556185422494,
#     'tknout': 'WETH-6Cc2',
#     'amtout': -0.008728072338626935,
#     'error': None}],
#   'WETH-6Cc2',
#   (CPCArbOptimizer.TradeInstruction(cid='173', tknin='WETH-6Cc2', amtin=0.008679729140554926, tknout='ANKR-EDD4', amtout=-521.8556255928706, error=None),
#    CPCArbOptimizer.TradeInstruction(cid='418', tknin='ANKR-EDD4', amtin=521.8556185422494, tknout='WETH-6Cc2', amtout=-0.008728072338626935, error=None))),
#  (Decimal('-0.2514557051909292311760351988'),
#               ENS-9D72  WETH-6Cc2
#   293        11.875559  -0.075290
#   363       -11.906274   0.075355
#   AMMIn      11.875559   0.075355
#   AMMOut    -11.906274  -0.075290
#   TOTAL NET  -0.030714   0.000065,
#   [{'cid': '293',
#     'tknin': 'ENS-9D72',
#     'amtin': 11.875559409607376,
#     'tknout': 'WETH-6Cc2',
#     'amtout': -0.07529025587423632,
#     'error': None},
#    {'cid': '363',
#     'tknin': 'WETH-6Cc2',
#     'amtin': 0.07535511202745226,
#     'tknout': 'ENS-9D72',
#     'amtout': -11.90627359629434,
#     'error': None}],
#   'WETH-6Cc2',
#   (CPCArbOptimizer.TradeInstruction(cid='293', tknin='ENS-9D72', amtin=11.875559409607376, tknout='WETH-6Cc2', amtout=-0.07529025587423632, error=None),
#    CPCArbOptimizer.TradeInstruction(cid='363', tknin='WETH-6Cc2', amtin=0.07535511202745226, tknout='ENS-9D72', amtout=-11.90627359629434, error=None))),
#  (Decimal('-3.526228742556851983435954153E-9'),
#              WETH-6Cc2  WBTC-C599
#   443              0.0        0.0
#   AMMIn            0.0        0.0
#   AMMOut           0.0        0.0
#   TOTAL NET        0.0        0.0,
#   [{'cid': '443',
#     'tknin': 'WETH-6Cc2',
#     'amtin': 0,
#     'tknout': 'WBTC-C599',
#     'amtout': 0,
#     'error': None}],
#   'WETH-6Cc2',
#   (CPCArbOptimizer.TradeInstruction(cid='443', tknin='WETH-6Cc2', amtin=0, tknout='WBTC-C599', amtout=0, error=None),)),
#  (Decimal('0.2666044339110980833478262759'),
#              WETH-6Cc2  FTX Token-a4c9
#   346         0.027135   -3.460340e+01
#   395        -0.027203    3.460340e+01
#   AMMIn       0.027135    3.460340e+01
#   AMMOut     -0.027203   -3.460340e+01
#   TOTAL NET  -0.000069    2.000888e-11,
#   [{'cid': '346',
#     'tknin': 'WETH-6Cc2',
#     'amtin': 0.02713455324125036,
#     'tknout': 'FTX Token-a4c9',
#     'amtout': -34.603401321533966,
#     'error': None},
#    {'cid': '395',
#     'tknin': 'FTX Token-a4c9',
#     'amtin': 34.603401321553974,
#     'tknout': 'WETH-6Cc2',
#     'amtout': -0.027203316596612126,
#     'error': None}],
#   'WETH-6Cc2',
#   (CPCArbOptimizer.TradeInstruction(cid='346', tknin='WETH-6Cc2', amtin=0.02713455324125036, tknout='FTX Token-a4c9', amtout=-34.603401321533966, error=None),
#    CPCArbOptimizer.TradeInstruction(cid='395', tknin='FTX Token-a4c9', amtin=34.603401321553974, tknout='WETH-6Cc2', amtout=-0.027203316596612126, error=None)))]

# %%
tn = r1.loc["TOTAL NET"].to_dict()
tntkn = list(set(tn.keys()) - {flt[0]})
print("TOTAL NET", tn)
print("TOKENS", tntkn, flt[0])
r1
# Out:
# TOTAL NET {'ENS-9D72': -0.03071418668696424, 'WETH-6Cc2': 6.485615321594196e-05}
# TOKENS ['ENS-9D72'] WETH-6Cc2
#             ENS-9D72  WETH-6Cc2
# 293        11.875559  -0.075290
# 363       -11.906274   0.075355
# AMMIn      11.875559   0.075355
# AMMOut    -11.906274  -0.075290
# TOTAL NET  -0.030714   0.000065

# %%
assert r1.loc["TOTAL NET"]["WETH-6Cc2"] < 1e-5, "Net change for WETH should be approximately zero"
assert abs(tn[tntkn[0]]) < 1e-5, f"{tntkn[0]} should be net zero {tn[tntkn[0]]}"
assert tn[flt[0]] < -0.00001, f"Arb value for {flt[0]} should be positive {-tn[flt[0]]}"
r1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-b30a7053605e> in <module>
# ----> 1 assert r1.loc["TOTAL NET"]["WETH-6Cc2"] < 1e-5, "Net change for WETH should be approximately zero"
#       2 assert abs(tn[tntkn[0]]) < 1e-5, f"{tntkn[0]} should be net zero {tn[tntkn[0]]}"
#       3 assert tn[flt[0]] < -0.00001, f"Arb value for {flt[0]} should be positive {-tn[flt[0]]}"
#       4 r1
#
# AssertionError: Net change for WETH should be approximately zero

# %%
assert len(r2) == 2, "There should be two items in the best_trade_instructions_dict"
r2

# %%
assert r3 == flt[0], "The best_src_token should be the flashloan token"
r3

# %%
assert len(r4) == 2, "There should be two items in the trade instructions"
r4

# %% [markdown]
# #### Full

# %%
r = bot._find_arbitrage_opportunities(flashloan_tokens=flt, CCm=CCm)

# %%
assert r[0] != 0, f"This setup should find an arb {r}"
r

# %% [markdown]
# ### Run `_run`

# %% [markdown]
# #### XS_ARBOPPS

# %%
ops = bot._run(flashloan_tokens=flt, CCm=CCm, result=bot.XS_ARBOPPS)
ops

# %%
# assert len(ops) == 5, "The best opportunity should populate correctly"
# assert ops[0] > 0, "There should be a profit"
# assert str(type(ops[1])) == "<class 'pandas.core.frame.DataFrame'>", "The df should be a df"
# assert type(ops[2]) == list, "The list of dicts should be a list"
# assert len(ops[2]) == 2, "In this example the list of dicts should have two items"
# assert type(ops[2][0]) == dict, "The the first item in the list of dicts should be a dict"
# assert len(ops[3].split('-')) == 2, "The best_src_token should be a token key"
# assert str(type(ops[4][0])) == "<class 'fastlane_bot.tools.optimizer.CPCArbOptimizer.TradeInstruction'>", "There should be trade instructions"

# %% [markdown]
# #### XS_ORDSCAL

# %%
ordscal = bot._run(flashloan_tokens=flt, CCm=CCm, result=bot.XS_ORDSCAL)
ordscal

# %%
# assert ops[2] != ordscal, 'After reordering AND scaling the two dicts should not be alike'
# assert set([x['cid'] for x in ops[2]]) == set([x['cid'] for x in ordscal]), 'The cids in should be those out'
# assert sum([x['amtin'] for x in ordscal]) < sum([x['amtin'] for x in ops[2]]), "After scaling the total amtin should be decreased"

# %% [markdown]
# #### XS_TI

# %%
xsti = bot._run(flashloan_tokens=flt, CCm=CCm, result=bot.XS_TI)
xsti

# %%
# assert str(type(xsti[0])) == "<class 'fastlane_bot.helpers.tradeinstruction.TradeInstruction'>", "After processing to TI the item should have trade instructions"
# assert sum([1 if xsti[i]._is_carbon else 0 for i in range(len(xsti))]) == 1, "In this example there should be a carbon order present identifiable from the TI object"
# assert xsti[0].db is not None, "A db should be present"
# assert xsti[0].ConfigObj is not None, "A configobj should be present"

# %% [markdown]
# #### XS_AGGTI

# %%
agg = bot._run(flashloan_tokens=flt, CCm=CCm, result=bot.XS_AGGTI)
agg

# %%
# assert agg[0].raw_txs != "[]", "In this case, the carbon order is first, when agg correctly the raw_txs should not be empty"
# assert agg[1].raw_txs == "[]", "In this case, the univ3 order is second, when agg correctly the raw_txs should be empty"

# %% [markdown]
# #### XS_ORDINFO

# %%
ordinfo = bot._run(flashloan_tokens=flt, CCm=CCm, result=bot.XS_ORDINFO)
ordinfo

# %%
# assert ordinfo[0] == agg, "The trade instructions should not have changed"
# assert ordinfo[1] > 0, "The flashloan amount should be greater than zero"
# assert ordinfo[2][:2] == '0x', "The flashloan address should start with 0x"

# %% [markdown]
# #### XS_ENCTI

# %%
enc = bot._run(flashloan_tokens=flt, CCm=CCm, result=bot.XS_ENCTI)
enc

# %%
# assert len(enc[0].custom_data) >= 258, "In this example, the carbon order is first so the custom data should have been populated with at least one set of instructions"
# assert enc[1].custom_data == '0x', "In this case, the univ3 order is second so the custom data should be only 0x"

# %% [markdown]
# #### XS_ROUTE

# %%
route = bot._run(flashloan_tokens=flt, CCm=CCm, result=bot.XS_ROUTE)
route

# %%
# assert len(route) ==2, 'In this example, there should be two parts to the route'
# assert type(route) == list, "The Route should be a list"
# assert type(route[0]) == dict, "Each instruction in the Route should be a dict"
# assert list(route[0].keys()) == ['exchangeId', 'targetToken', 'minTargetAmount', 'deadline', 'customAddress', 'customInt', 'customData'], "All keys should be present"
# assert list(route[1].keys()) == ['exchangeId', 'targetToken', 'minTargetAmount', 'deadline', 'customAddress', 'customInt', 'customData'], "All keys should be present"

# %%
# assert type(route[0]['exchangeId']) == int, "Exchange ids should be ints"
# assert type(route[0]['targetToken']) == str, "targetToken should be str"
# assert type(route[0]['minTargetAmount']) == int, "minTargetAmount should be ints"
# assert type(route[0]['deadline']) == int, "deadline should be ints"
# assert type(route[0]['customAddress']) == str, "customAddress should be str"
# assert type(route[0]['customInt']) == int, "customInt should be ints"
# assert type(route[0]['customData']) == str, "customData should be str"
