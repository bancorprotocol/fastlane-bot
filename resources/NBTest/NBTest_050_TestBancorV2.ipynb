# %%
# coding=utf-8
"""
This module contains the tests for the exchanges classes
"""
from fastlane_bot import Bot, Config
from fastlane_bot.bot import CarbonBot
from fastlane_bot.tools.cpc import ConstantProductCurve
from fastlane_bot.tools.cpc import ConstantProductCurve as CPC
from fastlane_bot.events.exchanges import UniswapV2, UniswapV3, SushiswapV2, CarbonV1, BancorV3
from fastlane_bot.events.interface import QueryInterface
from fastlane_bot.helpers.poolandtokens import PoolAndTokens
from fastlane_bot.helpers import TradeInstruction, TxReceiptHandler, TxRouteHandler, TxSubmitHandler, TxHelpers, TxHelper
from fastlane_bot.events.managers.manager import Manager
from fastlane_bot.events.interface import QueryInterface
from joblib import Parallel, delayed
from fastlane_bot.tools.cpc import ConstantProductCurve as CPC, CPCContainer, T
from dataclasses import dataclass, asdict, field
import pytest
import math
import json
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(CPC))
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(Bot))
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(UniswapV2))
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(UniswapV3))
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(SushiswapV2))
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(CarbonV1))
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(BancorV3))
from fastlane_bot.testing import *
from fastlane_bot.modes import triangle_single_bancor3
#plt.style.use('seaborn-dark')
plt.rcParams['figure.figsize'] = [12,6]
from fastlane_bot import __VERSION__
require("3.0", __VERSION__)
# Out:
# ConstantProductCurve v3.2 (15/Sep/2023)
# CarbonBot v3-b2.2 (20/June/2023)
# UniswapV2 v0.0.2 (2023-08-27)
# UniswapV3 v0.0.2 (2023-08-27)
# SushiswapV2 v0.0.2 (2023-08-27)
# CarbonV1 v0.0.2 (2023-08-27)
# BancorV3 v0.0.2 (2023-08-27)
# imported m, np, pd, plt, os, sys, decimal; defined iseq, raises, require
# Version = 3-b2.2 [requirements >= 3.0 is met]

# %% [markdown]
# # BancorV2Test [NB050]

# %%
C = cfg = Config.new(config=Config.CONFIG_MAINNET)
C.DEFAULT_MIN_PROFIT_BNT = 0.02
C.DEFAULT_MIN_PROFIT = 0.02
cfg.DEFAULT_MIN_PROFIT_BNT = 0.02
cfg.DEFAULT_MIN_PROFIT = 0.02
assert (C.NETWORK == C.NETWORK_MAINNET)
assert (C.PROVIDER == C.PROVIDER_ALCHEMY)
setup_bot = CarbonBot(ConfigObj=C)
pools = None

with open('fastlane_bot/data/tests/latest_pool_data_testing_bancor_v2.json') as f:
    pools = json.load(f)
pools = [pool for pool in pools]
pools[0]
static_pools = pools
state = pools
exchanges = list({ex['exchange_name'] for ex in state})
db = QueryInterface(state=state, ConfigObj=C, exchanges=exchanges)
setup_bot.db = db

static_pool_data_filename = "static_pool_data"

static_pool_data = pd.read_csv(f"fastlane_bot/data/{static_pool_data_filename}.csv", low_memory=False)
    
uniswap_v2_event_mappings = pd.read_csv("fastlane_bot/data/uniswap_v2_event_mappings.csv", low_memory=False)
        
tokens = pd.read_csv("fastlane_bot/data/tokens.csv", low_memory=False)
        
exchanges = "carbon_v1,bancor_v3,uniswap_v3,uniswap_v2,sushiswap_v2"

exchanges = exchanges.split(",")


alchemy_max_block_fetch = 20
static_pool_data["cid"] = [
        cfg.w3.keccak(text=f"{row['descr']}").hex()
        for index, row in static_pool_data.iterrows()
    ]
# Filter out pools that are not in the supported exchanges
static_pool_data = [
    row for index, row in static_pool_data.iterrows()
    if row["exchange_name"] in exchanges
]

static_pool_data = pd.DataFrame(static_pool_data)
static_pool_data['exchange_name'].unique()
# Initialize data fetch manager
mgr = Manager(
    web3=cfg.w3,
    cfg=cfg,
    pool_data=static_pool_data.to_dict(orient="records"),
    SUPPORTED_EXCHANGES=exchanges,
    alchemy_max_block_fetch=alchemy_max_block_fetch,
    uniswap_v2_event_mappings=uniswap_v2_event_mappings,
    tokens=tokens.to_dict(orient="records"),
)

# Add initial pools for each row in the static_pool_data
start_time = time.time()
Parallel(n_jobs=-1, backend="threading")(
    delayed(mgr.add_pool_to_exchange)(row) for row in mgr.pool_data
)
cfg.logger.info(f"Time taken to add initial pools: {time.time() - start_time}")

# check if any duplicate cid's exist in the pool data
mgr.deduplicate_pool_data()
cids = [pool["cid"] for pool in mgr.pool_data]
assert len(cids) == len(set(cids)), "duplicate cid's exist in the pool data"
def init_bot(mgr: Manager) -> CarbonBot:
    """
    Initializes the bot.

    Parameters
    ----------
    mgr : Manager
        The manager object.

    Returns
    -------
    CarbonBot
        The bot object.
    """
    mgr.cfg.logger.info("Initializing the bot...")
    bot = CarbonBot(ConfigObj=mgr.cfg)
    bot.db = db
    bot.db.mgr = mgr
    assert isinstance(
        bot.db, QueryInterface
    ), "QueryInterface not initialized correctly"
    return bot
bot = init_bot(mgr)
# add data cleanup steps from main.py
bot.db.handle_token_key_cleanup()
bot.db.remove_unmapped_uniswap_v2_pools()
bot.db.remove_zero_liquidity_pools()
bot.db.remove_unsupported_exchanges()
tokens = bot.db.get_tokens()
ADDRDEC = {t.key: (t.address, int(t.decimals)) for t in tokens if not math.isnan(t.decimals)}
flashloan_tokens = bot.setup_flashloan_tokens(None)
CCm = bot.setup_CCm(None)
pools = db.get_pool_data_with_tokens()

arb_mode = "multi"
# Out:
# 2023-09-20 18:23:56,830 [fastlane:INFO] -
# 2023-09-20 18:23:56,831 [fastlane:INFO] - **********************************************
# 2023-09-20 18:23:56,831 [fastlane:INFO] - The logging path is set to: logs/20230920-182356/bot.log
# 2023-09-20 18:23:56,832 [fastlane:INFO] - **********************************************
# 2023-09-20 18:23:56,833 [fastlane:INFO] -
# 2023-09-20 18:23:58,738 [fastlane:INFO] - Retrieved 169 carbon pairs from contract
# 2023-09-20 18:23:59,760 [fastlane:INFO] - Time taken to add initial pools: 0.1422710418701172
# 2023-09-20 18:23:59,765 [fastlane:INFO] - Initializing the bot...
# 2023-09-20 18:23:59,982 [fastlane:INFO] - Removed 3248 unmapped uniswap_v2/sushi pools. 2086 uniswap_v2/sushi pools remaining
# 2023-09-20 18:23:59,982 [fastlane:INFO] - Unmapped uniswap_v2/sushi pools:
# 2023-09-20 18:24:00,291 [fastlane:INFO] - uniswap_v3: 0
# 2023-09-20 18:24:00,292 [fastlane:INFO] - uniswap_v2: 3248
# 2023-09-20 18:24:00,292 [fastlane:INFO] - sushiswap_v2: 0
# 2023-09-20 18:24:00,295 [fastlane:INFO] - uniswap_v3: 1232
# 2023-09-20 18:24:00,295 [fastlane:INFO] - sushiswap_v2: 106
# 2023-09-20 18:24:00,296 [fastlane:INFO] - uniswap_v2: 0
# 2023-09-20 18:24:00,296 [fastlane:INFO] - bancor_v2: 100
# 2023-09-20 18:24:00,297 [fastlane:INFO] - bancor_v3: 28
# 2023-09-20 18:24:00,297 [fastlane:INFO] - carbon_v1: 315
# 2023-09-20 18:24:00,368 [fastlane:INFO] - uniswap_v3_zero_liquidity_pools: 262
# 2023-09-20 18:24:00,368 [fastlane:INFO] - sushiswap_v2_zero_liquidity_pools: 0
# 2023-09-20 18:24:00,369 [fastlane:INFO] - uniswap_v2_zero_liquidity_pools: 0
# 2023-09-20 18:24:00,369 [fastlane:INFO] - bancor_v2_zero_liquidity_pools: 0
# 2023-09-20 18:24:00,370 [fastlane:INFO] - bancor_v3_zero_liquidity_pools: 43
# 2023-09-20 18:24:00,370 [fastlane:INFO] - carbon_v1_zero_liquidity_pools: 0
# 2023-09-20 18:24:00,371 [fastlane:INFO] - Removed 0 unsupported exchanges. 1781 pools remaining
# 2023-09-20 18:24:00,372 [fastlane:INFO] - Pools remaining per exchange:
# 2023-09-20 18:24:00,373 [fastlane:INFO] - uniswap_v3: 1232
# 2023-09-20 18:24:00,373 [fastlane:INFO] - sushiswap_v2: 106
# 2023-09-20 18:24:00,374 [fastlane:INFO] - bancor_v2: 100
# 2023-09-20 18:24:00,375 [fastlane:INFO] - uniswap_v2: 0
# 2023-09-20 18:24:00,376 [fastlane:INFO] - bancor_v3: 28
# 2023-09-20 18:24:00,377 [fastlane:INFO] - carbon_v1: 315

# %% [markdown]
# ## Test_MIN_PROFIT

# %%
assert(cfg.DEFAULT_MIN_PROFIT_BNT <= 0.02), f"[TestMultiMode], DEFAULT_MIN_PROFIT_BNT must be <= 0.02 for this Notebook to run, currently set to {cfg.DEFAULT_MIN_PROFIT_BNT}"
assert(C.DEFAULT_MIN_PROFIT_BNT <= 0.02), f"[TestMultiMode], DEFAULT_MIN_PROFIT_BNT must be <= 0.02 for this Notebook to run, currently set to {cfg.DEFAULT_MIN_PROFIT_BNT}"

# %% [markdown]
# ## Test_Combos_and_Tokens

# %%
arb_finder = bot._get_arb_finder("multi")
finder2 = arb_finder(
            flashloan_tokens=flashloan_tokens,
            CCm=CCm,
            mode="bothin",
            result=bot.AO_TOKENS,
            ConfigObj=bot.ConfigObj,
        )
all_tokens, combos = finder2.find_arbitrage()
assert len(all_tokens) == 971, f"[NBTest_50_TestBancorV2] Using wrong dataset, expected 971 tokens, found {len(all_tokens)}"
assert len(combos) == 5820, f"[NBTest_50_TestBancorV2] Using wrong dataset, expected 5820 tokens, found {len(combos)}"

# %% [markdown]
# ## Test_Expected_Output_BancorV2

# %%
run_full = bot._run(flashloan_tokens=flashloan_tokens, CCm=CCm, arb_mode=arb_mode, data_validator=False, result=bot.XS_ARBOPPS)
arb_finder = bot._get_arb_finder("multi")
finder = arb_finder(
            flashloan_tokens=flashloan_tokens,
            CCm=CCm,
            mode="bothin",
            result=bot.AO_CANDIDATES,
            ConfigObj=bot.ConfigObj,
        )
r = finder.find_arbitrage()
arb_with_bancor_v2 = []

for arb_opp in r:
    pools = []
    for pool in arb_opp[2]:
        pools += [curve for curve in CCm if curve.cid == pool['cid']]
    for pool in pools:
        if pool.params['exchange'] == "bancor_v2":
            arb_with_bancor_v2.append(arb_opp)

# get specific arb for tests

test_arb = None

test_cids = ['0x297f9a0e8d3f57de8c62a8fde0ff09193b934ff0ae906085526f0b97b90e188a', '3743106036130323098097120681749450326076-0', '3743106036130323098097120681749450326076-1']

for arb in arb_with_bancor_v2:
    all_match = True
    for pool in arb[2]:
        if pool['cid'] not in test_cids:
            all_match = False
    
    if all_match:
        test_arb = arb

(
    best_profit,
    best_trade_instructions_df,
    best_trade_instructions_dic,
    best_src_token,
    best_trade_instructions,
) = test_arb

# Order the trade instructions
(
    ordered_trade_instructions_dct,
    tx_in_count,
) = bot._simple_ordering_by_src_token(
    best_trade_instructions_dic, best_src_token
)

# Scale the trade instructions
ordered_scaled_dcts = bot._basic_scaling(
    ordered_trade_instructions_dct, best_src_token
)

# Convert the trade instructions
ordered_trade_instructions_objects = bot._convert_trade_instructions(
    ordered_scaled_dcts
)

# Create the tx route handler
tx_route_handler = bot.TxRouteHandlerClass(
    trade_instructions=ordered_trade_instructions_objects
)

# Aggregate the carbon trades
agg_trade_instructions = (
    tx_route_handler.aggregate_carbon_trades(ordered_trade_instructions_objects)
    if bot._carbon_in_trade_route(ordered_trade_instructions_objects)
    else ordered_trade_instructions_objects
)

# Calculate the trade instructions
calculated_trade_instructions = tx_route_handler.calculate_trade_outputs(
    agg_trade_instructions
)

# Aggregate multiple Bancor V3 trades into a single trade
calculated_trade_instructions = tx_route_handler.aggregate_bancor_v3_trades(
    calculated_trade_instructions
)

# Get the flashloan token
fl_token = fl_token_with_weth = calculated_trade_instructions[0].tknin_key

# If the flashloan token is WETH, then use ETH
if fl_token == T.WETH:
    fl_token = T.NATIVE_ETH

best_profit = flashloan_tkn_profit = tx_route_handler.calculate_trade_profit(calculated_trade_instructions)

# Use helper function to calculate profit
best_profit, flt_per_bnt, profit_usd = bot.calculate_profit(
    CCm, best_profit, fl_token, fl_token_with_weth
)

# Check if the best profit is greater than the minimum profit
if best_profit < bot.ConfigObj.DEFAULT_MIN_PROFIT:
    bot.ConfigObj.logger.info(
        f"Opportunity with profit: {num_format(best_profit)} does not meet minimum profit: {self.ConfigObj.DEFAULT_MIN_PROFIT}, discarding."
    )

# Get the flashloan amount and token address
flashloan_amount = int(calculated_trade_instructions[0].amtin_wei)
flashloan_token_address = bot.ConfigObj.w3.toChecksumAddress(
    bot.db.get_token(key=fl_token).address
)

# Encode the trade instructions
encoded_trade_instructions = tx_route_handler.custom_data_encoder(
    calculated_trade_instructions
)

# Get the deadline
deadline = bot._get_deadline(1)

# Get the route struct
route_struct = [
    asdict(rs)
    for rs in tx_route_handler.get_route_structs(
        encoded_trade_instructions, deadline
    )
]
assert arb_finder.__name__ == "FindArbitrageMultiPairwise", f"[NBTest_50_TestBancorV2] Expected arb_finder class name name = FindArbitrageMultiPairwise, found {arb_finder.__name__}"
assert len(r) == 41, f"[NBTest_50_TestBancorV2] Expected 41 arb opps, found {len(r)}"
assert len(arb_with_bancor_v2) == 4, f"[NBTest_50_TestBancorV2] Expected 4 arb opps with Bancor V2 pools, found {len(arb_with_bancor_v2)}"
assert encoded_trade_instructions[0].amtin * 10 ** 18 == flashloan_amount, f"[NBTest_50_TestBancorV2] First trade in should match flashloan amount"
assert route_struct[0]['customAddress'] == "0xb1CD6e4153B2a390Cf00A6556b0fC1458C4A5533" or route_struct[1]['customAddress'] == "0xb1CD6e4153B2a390Cf00A6556b0fC1458C4A5533", f"[NBTest_50_TestBancorV2] customAddress for Bancor V2.1 trade must be converter token address, expected: 0xb1CD6e4153B2a390Cf00A6556b0fC1458C4A5533 for one address, found: {route_struct[0]['customAddress']} and {route_struct[1]['customAddress']}"
# Out:
# [PairOptimizer.optimize] curves_t LDO-1B32/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.5512199017275474, method='bisection', errormsg=None, context_dct=None) full_result [-3.18323146e-11  5.00222086e-11]
# [PairOptimizer.optimize] curves_t LDO-1B32/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.5503158643414845, method='bisection', errormsg=None, context_dct=None) full_result [ 6.63931132e-11 -1.03000275e-10]
# [PairOptimizer.optimize] curves_t LYXe-be6D/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.0040613519230443765, method='bisection', errormsg=None, context_dct=None) full_result [ 2.24099495e-09 -9.09494702e-12]
# [PairOptimizer.optimize] curves_t LYXe-be6D/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.004091605713319712, method='bisection', errormsg=None, context_dct=None) full_result [-9.32777766e-09  3.81419341e-11]
# [PairOptimizer.optimize] curves_t icETH-6A84/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0696163679651205, method='bisection', errormsg=None, context_dct=None) full_result [-5.23868948e-10 -4.83012080e-03]
# [PairOptimizer.optimize] curves_t ankrETH-c3cb/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.1209999708541414, method='bisection', errormsg=None, context_dct=None) full_result [-1.70414296e-08 -1.95835453e-05]
# [PairOptimizer.optimize] curves_t wTAO-0A44/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=59.75533968980015, method='bisection', errormsg=None, context_dct=None) full_result [-7.77617970e-11  4.64933692e-09]
# [PairOptimizer.optimize] curves_t RPL-A51f/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.01398051036505616, method='bisection', errormsg=None, context_dct=None) full_result [ 8.62637535e-08 -5.64897200e-04]
# [PairOptimizer.optimize] curves_t RPL-A51f/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.013965304969464052, method='bisection', errormsg=None, context_dct=None) full_result [-1.60071068e-08 -5.81552275e-04]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25894.11357044658, method='bisection', errormsg=None, context_dct=None) full_result [-1.82751592e-11 -1.10195462e+00]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=26221.251313448258, method='bisection', errormsg=None, context_dct=None) full_result [-1.19904087e-12 -9.88980061e-01]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25947.264020257608, method='bisection', errormsg=None, context_dct=None) full_result [-6.90761226e-10 -1.08353598e+00]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25860.496138908864, method='bisection', errormsg=None, context_dct=None) full_result [ 1.13908882e-13 -2.94312485e-09]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25958.88738935483, method='bisection', errormsg=None, context_dct=None) full_result [ 1.04023457e-10 -2.70083547e-06]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.790406758733166, method='bisection', errormsg=None, context_dct=None) full_result [-1.60071068e-09 -2.26421980e-05]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.812775147298701, method='bisection', errormsg=None, context_dct=None) full_result [ 7.43556713e-07 -1.17917498e-05]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.817111773149229, method='bisection', errormsg=None, context_dct=None) full_result [-2.50466314e-13 -8.17544787e-09]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.786713068791116, method='bisection', errormsg=None, context_dct=None) full_result [ 3.44152795e-09 -2.64644623e-05]
# [PairOptimizer.optimize] curves_t rETH-6393/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0849516612439125, method='bisection', errormsg=None, context_dct=None) full_result [ 1.26565425e-12 -1.37312384e-12]
# [PairOptimizer.optimize] curves_t rETH-6393/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0832081729931682, method='bisection', errormsg=None, context_dct=None) full_result [-3.53902578e-08  3.84170562e-08]
# [PairOptimizer.optimize] curves_t LINK-86CA/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=5.909970444253293, method='bisection', errormsg=None, context_dct=None) full_result [-7.45058060e-09 -4.20425425e-02]
# [PairOptimizer.optimize] curves_t LINK-86CA/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=14.476353182200608, method='bisection', errormsg=None, context_dct=None) full_result [-1.23254722e-08 -1.24618688e+00]
# [PairOptimizer.optimize] curves_t LINK-86CA/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=14.423416123500672, method='bisection', errormsg=None, context_dct=None) full_result [-1.37952156e-07 -1.35431341e+00]
# [PairOptimizer.optimize] curves_t LINK-86CA/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=6.025304359733498, method='bisection', errormsg=None, context_dct=None) full_result [-1.00726538e-10 -1.93268756e-01]
# [PairOptimizer.optimize] curves_t LINK-86CA/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.003598376343563188, method='bisection', errormsg=None, context_dct=None) full_result [ 8.20493733e-06 -1.66398396e-03]
# [PairOptimizer.optimize] curves_t LINK-86CA/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.0036363942004329986, method='bisection', errormsg=None, context_dct=None) full_result [ 1.09139364e-09 -1.48144074e-03]
# [PairOptimizer.optimize] curves_t frxETH-Aa1f/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9985013740388335, method='bisection', errormsg=None, context_dct=None) full_result [ 2.99769454e-08 -2.99187377e-08]
# [PairOptimizer.optimize] curves_t ETH2x_FLI-65BD/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.005673566368387039, method='bisection', errormsg=None, context_dct=None) full_result [-2.27191777e-08 -4.55839243e-04]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0000297312508728, method='bisection', errormsg=None, context_dct=None) full_result [-0.0423584  0.0423584]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.002690120951899, method='bisection', errormsg=None, context_dct=None) full_result [ 3.80168785e-09 -5.07036893e-05]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0004247950329712, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00736237 -0.00736237]
# [PairOptimizer.optimize] curves_t BNT-FF1C/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40956852534106775, method='bisection', errormsg=None, context_dct=None) full_result [ 1.65076926e-07 -6.76373020e-08]
# [PairOptimizer.optimize] curves_t BNT-FF1C/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40956852534106775, method='bisection', errormsg=None, context_dct=None) full_result [ 1.65076926e-07 -6.76373020e-08]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0005488018089181, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00167465 -0.00167561]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0006773070202648, method='bisection', errormsg=None, context_dct=None) full_result [ 4.02629375e-05 -4.02927399e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.0888898281764, method='bisection', errormsg=None, context_dct=None) full_result [-8.68457102e-04 -1.42722342e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.0888898281764, method='bisection', errormsg=None, context_dct=None) full_result [-8.68457102e-04 -1.42722342e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.9498309465775, method='bisection', errormsg=None, context_dct=None) full_result [-6.53943172e-04  1.92292873e-07]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.9498309465775, method='bisection', errormsg=None, context_dct=None) full_result [-6.53943172e-04  1.92292873e-07]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.4034882815731, method='bisection', errormsg=None, context_dct=None) full_result [-8.63196181e-04  7.39900770e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.4034882815731, method='bisection', errormsg=None, context_dct=None) full_result [-8.63196181e-04  7.39900770e-06]
# [PairOptimizer.optimize] curves_t vBNT-7f94/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.8036398452964134, method='bisection', errormsg=None, context_dct=None) full_result [-3.84989107e-09 -3.68013790e+00]
# [PairOptimizer.optimize] curves_t vBNT-7f94/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.806576166124066, method='bisection', errormsg=None, context_dct=None) full_result [ 2.79530468e-07 -3.84077211e+00]
# [PairOptimizer.optimize] curves_t BITCOIN-EEa9/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=5.0517343489295036e-05, method='bisection', errormsg=None, context_dct=None) full_result [-2.77906656e-06 -4.74165511e-03]
# [PairOptimizer.optimize] curves_t SMT-7173/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4.04750820442226e-05, method='bisection', errormsg=None, context_dct=None) full_result [ 4.20259312e-08 -1.69464442e-12]
# [PairOptimizer.optimize] curves_t HEX-eb39/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=2.2536858410029086e-06, method='bisection', errormsg=None, context_dct=None) full_result [-2.25194979e-05 -2.79062834e-03]
# [PairOptimizer.optimize] curves_t HEX-eb39/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=2.4823759353487097e-06, method='bisection', errormsg=None, context_dct=None) full_result [ 2.48465062e-06 -2.65818821e-03]
# [PairOptimizer.optimize] curves_t SNX-2a6F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=2.1056696298978608, method='bisection', errormsg=None, context_dct=None) full_result [ 1.76078174e-08 -3.70782800e-08]
# [PairOptimizer.optimize] curves_t SNX-2a6F/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.0012840522461291283, method='bisection', errormsg=None, context_dct=None) full_result [-1.31898560e-07 -3.86341488e-05]
# [PairOptimizer.optimize] curves_t SNX-2a6F/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.001299999873338579, method='bisection', errormsg=None, context_dct=None) full_result [-4.24727750e-06 -4.54139488e-05]
# [PairOptimizer.optimize] curves_t LUSD-8bA0/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9978724602785255, method='bisection', errormsg=None, context_dct=None) full_result [-7.68899918e-06  7.68899918e-06]
# [PairOptimizer.optimize] curves_t LUSD-8bA0/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0138104005170503, method='bisection', errormsg=None, context_dct=None) full_result [ 7.52606866e-11 -1.44194436e-02]
# [PairOptimizer.optimize] curves_t FXS-64D0/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.00357782089888243, method='bisection', errormsg=None, context_dct=None) full_result [ 1.73691660e-07 -6.21639629e-10]
# [PairOptimizer.optimize] curves_t FXS-64D0/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.0035945871952937315, method='bisection', errormsg=None, context_dct=None) full_result [ 4.68571670e-09 -1.68540737e-11]
# 2023-09-20 18:24:01,713 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:01,720 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:01,831 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:01,840 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# [PairOptimizer.optimize] curves_t PEPE-1933/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=8.740970973666416e-07, method='bisection', errormsg=None, context_dct=None) full_result [-0.00129128 -0.77419953]
# [PairOptimizer.optimize] curves_t PEPE-1933/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=5.277344709106788e-10, method='bisection', errormsg=None, context_dct=None) full_result [ 1.81250000e+00 -9.60426405e-10]
# [PairOptimizer.optimize] curves_t PEPE-1933/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=5.269990466066394e-10, method='bisection', errormsg=None, context_dct=None) full_result [-1.41296387e-02  7.43227702e-12]
# [PairOptimizer.optimize] curves_t BNT-FF1C/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40894531356880626, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00000000e+00 -5.82076609e-11]
# [PairOptimizer.optimize] curves_t BNT-FF1C/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.4086633555055692, method='bisection', errormsg=None, context_dct=None) full_result [-1.66706741e-07  6.82193786e-08]
# [PairOptimizer.optimize] curves_t BNT-FF1C/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40956852534106775, method='bisection', errormsg=None, context_dct=None) full_result [ 1.65076926e-07 -6.76373020e-08]
# [PairOptimizer.optimize] curves_t BNT-FF1C/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40956852534106775, method='bisection', errormsg=None, context_dct=None) full_result [ 1.65076926e-07 -6.76373020e-08]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4054.529791408447, method='bisection', errormsg=None, context_dct=None) full_result [-1.31113473e-03  3.20131221e-07]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4027.34045123578, method='bisection', errormsg=None, context_dct=None) full_result [-7.09732499e-04 -7.77050445e-07]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9994682546420484, method='bisection', errormsg=None, context_dct=None) full_result [-0.00151062  0.00150299]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9993895090795277, method='bisection', errormsg=None, context_dct=None) full_result [-4.89787199e-05 -2.38863403e-01]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9996477810760712, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00054311 -0.04411559]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25860.496138908864, method='bisection', errormsg=None, context_dct=None) full_result [ 1.13908882e-13 -2.94312485e-09]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25958.88738935483, method='bisection', errormsg=None, context_dct=None) full_result [ 1.04023457e-10 -2.70083547e-06]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0005488018089181, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00167465 -0.00167561]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0006773070202648, method='bisection', errormsg=None, context_dct=None) full_result [ 4.02629375e-05 -4.02927399e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1642.5356619969218, method='bisection', errormsg=None, context_dct=None) full_result [-6.5920176e-09  1.0818243e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1642.2054156236097, method='bisection', errormsg=None, context_dct=None) full_result [ 5.18048182e-09 -8.50856304e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.2158188881624, method='bisection', errormsg=None, context_dct=None) full_result [-3.64934749e-11  6.00703061e-08]
# [PairOptimizer.optimize] curves_t CRV-cd52/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.5128121576444096, method='bisection', errormsg=None, context_dct=None) full_result [ 8.79936124e-11 -6.93504009e-01]
# [PairOptimizer.optimize] curves_t CRV-cd52/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.47848668347779655, method='bisection', errormsg=None, context_dct=None) full_result [ 1.90603089e-12 -9.12159237e-13]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.637151483858, method='bisection', errormsg=None, context_dct=None) full_result [ 2.04153607e-08 -5.50687291e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDC-eB48
# 2023-09-20 18:24:02,182 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:02,211 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:02,239 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1652.6435722541178, method='bisection', errormsg=None, context_dct=None) full_result [-9.33941813e-12 -2.83163575e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4054.522266683849, method='bisection', errormsg=None, context_dct=None) full_result [-2.96278557e-11 -5.31602944e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4027.3389732416063, method='bisection', errormsg=None, context_dct=None) full_result [-4.36228831e-10 -2.85833290e+00]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.790406759966878, method='bisection', errormsg=None, context_dct=None) full_result [-1.43223588e-06 -5.19212335e-08]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.812775147298701, method='bisection', errormsg=None, context_dct=None) full_result [ 7.43556713e-07 -1.17917498e-05]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.817111774588557, method='bisection', errormsg=None, context_dct=None) full_result [-5.19674970e-10  4.03588274e-11]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.786713069892642, method='bisection', errormsg=None, context_dct=None) full_result [-1.66444079e-06 -1.33994035e-07]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.0887576656314, method='bisection', errormsg=None, context_dct=None) full_result [ 4.21567847e-09 -1.42522359e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.0887576656314, method='bisection', errormsg=None, context_dct=None) full_result [ 4.21567847e-09 -1.42522359e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.9470071390738, method='bisection', errormsg=None, context_dct=None) full_result [-5.89639448e-13 -1.08224203e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.9470071390738, method='bisection', errormsg=None, context_dct=None) full_result [-5.89639448e-13 -1.08224203e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.4033940136069, method='bisection', errormsg=None, context_dct=None) full_result [ 4.26534763e-09 -1.41685278e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.4033940136069, method='bisection', errormsg=None, context_dct=None) full_result [ 4.26534763e-09 -1.41685278e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1642.5356619969218, method='bisection', errormsg=None, context_dct=None) full_result [-6.5920176e-09  1.0818243e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1642.2054156236097, method='bisection', errormsg=None, context_dct=None) full_result [ 5.18048182e-09 -8.50856304e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.2158188881624, method='bisection', errormsg=None, context_dct=None) full_result [-3.64934749e-11  6.00703061e-08]
# [PairOptimizer.optimize] curves_t BNT-FF1C/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40894531356880626, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00000000e+00 -5.82076609e-11]
# [PairOptimizer.optimize] curves_t BNT-FF1C/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.4086633555055692, method='bisection', errormsg=None, context_dct=None) full_result [-1.66706741e-07  6.82193786e-08]
# [PairOptimizer.optimize] curves_t
# 2023-09-20 18:24:02,345 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:02,352 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:02,360 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
#  WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25894.125440594566, method='bisection', errormsg=None, context_dct=None) full_result [-4.25562189e-05  7.28294253e-07]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=26221.377901962558, method='bisection', errormsg=None, context_dct=None) full_result [-3.77166493e-05  3.39932740e-08]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25947.264438634636, method='bisection', errormsg=None, context_dct=None) full_result [-4.17604274e-05  1.49533153e-05]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0000297312508728, method='bisection', errormsg=None, context_dct=None) full_result [-0.0423584  0.0423584]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0026901251167768, method='bisection', errormsg=None, context_dct=None) full_result [-5.05640273e-05  1.74622983e-10]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0004247950329712, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00736237 -0.00736237]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9994682546420484, method='bisection', errormsg=None, context_dct=None) full_result [-0.00151062  0.00150299]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9993895100725572, method='bisection', errormsg=None, context_dct=None) full_result [-2.39100285e-01  4.19931021e-05]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9996477811013805, method='bisection', errormsg=None, context_dct=None) full_result [-4.35143951e-02 -7.33835623e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.6372358260983, method='bisection', errormsg=None, context_dct=None) full_result [-3.35446311e-03 -2.80184399e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1652.6462448793209, method='bisection', errormsg=None, context_dct=None) full_result [-1.71339668e-03  5.45598141e-07]
# [PairOptimizer.optimize] curves_t LDO-1B32/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.5512199017275474, method='bisection', errormsg=None, context_dct=None) full_result [-3.18323146e-11  5.00222086e-11]
# [PairOptimizer.optimize] curves_t LDO-1B32/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.5503158643414845, method='bisection', errormsg=None, context_dct=None) full_result [ 6.63931132e-11 -1.03000275e-10]
# [PairOptimizer.optimize] curves_t LYXe-be6D/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.0040613519230443765, method='bisection', errormsg=None, context_dct=None) full_result [ 2.24099495e-09 -9.09494702e-12]
# [PairOptimizer.optimize] curves_t LYXe-be6D/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.004091605713319712, method='bisection', errormsg=None, context_dct=None) full_result [-9.32777766e-09  3.81419341e-11]
# [PairOptimizer.optimize] curves_t icETH-6A84/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0696163679651205, method='bisection', errormsg=None, context_dct=None) full_result [-5.23868948e-10 -4.83012080e-03]
# [PairOptimizer.optimize] curves_t ankrETH-c3cb/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.1209999708541414, method='bisection', errormsg=None, context_dct=None) full_result [-1.70414296e-08 -1.95835453e-05]
# [PairOptimizer.optimize] curves_t wTAO-0A44/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=59.75533968980015, method='bisection', errormsg=None, context_dct=None) full_result [-7.77617970e-11  4.64933692e-09]
# [PairOptimizer.optimize] curves_t RPL-A51f/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.01398051036505616, method='bisection', errormsg=None, context_dct=None) full_result [ 8.62637535e-08 -5.64897200e-04]
# [PairOptimizer.optimize] curves_t RPL-A51f/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.013965304969464052, method='bisection', errormsg=None, context_dct=None) full_result [-1.60071068e-08 -5.81552275e-04]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25894.11357044658, method='bisection', errormsg=None, context_dct=None) full_result [-1.82751592e-11 -1.10195462e+00]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=26221.251313448258, method='bisection', errormsg=None, context_dct=None) full_result [-1.19904087e-12 -9.88980061e-01]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25947.264020257608, method='bisection', errormsg=None, context_dct=None) full_result [-6.90761226e-10 -1.08353598e+00]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25860.496138908864, method='bisection', errormsg=None, context_dct=None) full_result [ 1.13908882e-13 -2.94312485e-09]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25958.88738935483, method='bisection', errormsg=None, context_dct=None) full_result [ 1.04023457e-10 -2.70083547e-06]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.790406758733166, method='bisection', errormsg=None, context_dct=None) full_result [-1.60071068e-09 -2.26421980e-05]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.812775147298701, method='bisection', errormsg=None, context_dct=None) full_result [ 7.43556713e-07 -1.17917498e-05]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.817111773149229, method='bisection', errormsg=None, context_dct=None) full_result [-2.50466314e-13 -8.17544787e-09]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.786713068791116, method='bisection', errormsg=None, context_dct=None) full_result [ 3.44152795e-09 -2.64644623e-05]
# [PairOptimizer.optimize] curves_t rETH-6393/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0849516612439125, method='bisection', errormsg=None, context_dct=None) full_result [ 1.26565425e-12 -1.37312384e-12]
# [PairOptimizer.optimize] curves_t rETH-6393/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0832081729931682, method='bisection', errormsg=None, context_dct=None) full_result [-3.53902578e-08  3.84170562e-08]
# [PairOptimizer.optimize] curves_t LINK-86CA/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=5.909970444253293, method='bisection', errormsg=None, context_dct=None) full_result [-7.45058060e-09 -4.20425425e-02]
# [PairOptimizer.optimize] curves_t LINK-86CA/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=14.476353182200608, method='bisection', errormsg=None, context_dct=None) full_result [-1.23254722e-08 -1.24618688e+00]
# [PairOptimizer.optimize] curves_t LINK-86CA/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=14.423416123500672, method='bisection', errormsg=None, context_dct=None) full_result [-1.37952156e-07 -1.35431341e+00]
# [PairOptimizer.optimize] curves_t LINK-86CA/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=6.025304359733498, method='bisection', errormsg=None, context_dct=None) full_result [-1.00726538e-10 -1.93268756e-01]
# [PairOptimizer.optimize] curves_t LINK-86CA/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.003598376343563188, method='bisection', errormsg=None, context_dct=None) full_result [ 8.20493733e-06 -1.66398396e-03]
# [PairOptimizer.optimize] curves_t LINK-86CA/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.0036363942004329986, method='bisection', errormsg=None, context_dct=None) full_result [ 1.09139364e-09 -1.48144074e-03]
# [PairOptimizer.optimize] curves_t frxETH-Aa1f/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9985013740388335, method='bisection', errormsg=None, context_dct=None) full_result [ 2.99769454e-08 -2.99187377e-08]
# [PairOptimizer.optimize] curves_t ETH2x_FLI-65BD/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.005673566368387039, method='bisection', errormsg=None, context_dct=None) full_result [-2.27191777e-08 -4.55839243e-04]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0000297312508728, method='bisection', errormsg=None, context_dct=None) full_result [-0.0423584  0.0423584]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.002690120951899, method='bisection', errormsg=None, context_dct=None) full_result [ 3.80168785e-09 -5.07036893e-05]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0004247950329712, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00736237 -0.00736237]
# [PairOptimizer.optimize] curves_t BNT-FF1C/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40956852534106775, method='bisection', errormsg=None, context_dct=None) full_result [ 1.65076926e-07 -6.76373020e-08]
# [PairOptimizer.optimize] curves_t BNT-FF1C/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40956852534106775, method='bisection', errormsg=None, context_dct=None) full_result [ 1.65076926e-07 -6.76373020e-08]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0005488018089181, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00167465 -0.00167561]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0006773070202648, method='bisection', errormsg=None, context_dct=None) full_result [ 4.02629375e-05 -4.02927399e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.0888898281764, method='bisection', errormsg=None, context_dct=None) full_result [-8.68457102e-04 -1.42722342e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.0888898281764, method='bisection', errormsg=None, context_dct=None) full_result [-8.68457102e-04 -1.42722342e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.9498309465775, method='bisection', errormsg=None, context_dct=None) full_result [-6.53943172e-04  1.92292873e-07]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.9498309465775, method='bisection', errormsg=None, context_dct=None) full_result [-6.53943172e-04  1.92292873e-07]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.4034882815731, method='bisection', errormsg=None, context_dct=None) full_result [-8.63196181e-04  7.39900770e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.4034882815731, method='bisection', errormsg=None, context_dct=None) full_result [-8.63196181e-04  7.39900770e-06]
# [PairOptimizer.optimize] curves_t vBNT-7f94/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.8036398452964134, method='bisection', errormsg=None, context_dct=None) full_result [-3.84989107e-09 -3.68013790e+00]
# [PairOptimizer.optimize] curves_t vBNT-7f94/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.806576166124066, method='bisection', errormsg=None, context_dct=None) full_result [ 2.79530468e-07 -3.84077211e+00]
# [PairOptimizer.optimize] curves_t BITCOIN-EEa9/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=5.0517343489295036e-05, method='bisection', errormsg=None, context_dct=None) full_result [-2.77906656e-06 -4.74165511e-03]
# [PairOptimizer.optimize] curves_t SMT-7173/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4.04750820442226e-05, method='bisection', errormsg=None, context_dct=None) full_result [ 4.20259312e-08 -1.69464442e-12]
# [PairOptimizer.optimize] curves_t HEX-eb39/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=2.2536858410029086e-06, method='bisection', errormsg=None, context_dct=None) full_result [-2.25194979e-05 -2.79062834e-03]
# [PairOptimizer.optimize] curves_t HEX-eb39/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=2.4823759353487097e-06, method='bisection', errormsg=None, context_dct=None) full_result [ 2.48465062e-06 -2.65818821e-03]
# [PairOptimizer.optimize] curves_t SNX-2a6F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=2.1056696298978608, method='bisection', errormsg=None, context_dct=None) full_result [ 1.76078174e-08 -3.70782800e-08]
# [PairOptimizer.optimize] curves_t SNX-2a6F/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.0012840522461291283, method='bisection', errormsg=None, context_dct=None) full_result [-1.31898560e-07 -3.86341488e-05]
# [PairOptimizer.optimize] curves_t SNX-2a6F/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.001299999873338579, method='bisection', errormsg=None, context_dct=None) full_result [-4.24727750e-06 -4.54139488e-05]
# [PairOptimizer.optimize] curves_t LUSD-8bA0/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9978724602785255, method='bisection', errormsg=None, context_dct=None) full_result [-7.68899918e-06  7.68899918e-06]
# [PairOptimizer.optimize] curves_t LUSD-8bA0/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0138104005170503, method='bisection', errormsg=None, context_dct=None) full_result [ 7.52606866e-11 -1.44194436e-02]
# [PairOptimizer.optimize] curves_t FXS-64D0/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.00357782089888243, method='bisection', errormsg=None, context_dct=None) full_result [ 1.73691660e-07 -6.21639629e-10]
# [PairOptimizer.optimize] curves_t FXS-64D0/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.0035945871952937315, method='bisection', errormsg=None, context_dct=None) full_result [ 4.68571670e-09 -1.68540737e-11]
# [PairOptimizer.optimize] curves_t PEPE-1933/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=8.740970973666416e-07, method='bisection', errormsg=None, context_dct=None) full_result [-0.00129128 -0.77419953]
# [PairOptimizer.optimize] curves_t
# 2023-09-20 18:24:03,576 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:03,583 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:03,677 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:03,685 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
#  PEPE-1933/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=5.277344709106788e-10, method='bisection', errormsg=None, context_dct=None) full_result [ 1.81250000e+00 -9.60426405e-10]
# [PairOptimizer.optimize] curves_t PEPE-1933/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=5.269990466066394e-10, method='bisection', errormsg=None, context_dct=None) full_result [-1.41296387e-02  7.43227702e-12]
# [PairOptimizer.optimize] curves_t BNT-FF1C/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40894531356880626, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00000000e+00 -5.82076609e-11]
# [PairOptimizer.optimize] curves_t BNT-FF1C/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.4086633555055692, method='bisection', errormsg=None, context_dct=None) full_result [-1.66706741e-07  6.82193786e-08]
# [PairOptimizer.optimize] curves_t BNT-FF1C/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40956852534106775, method='bisection', errormsg=None, context_dct=None) full_result [ 1.65076926e-07 -6.76373020e-08]
# [PairOptimizer.optimize] curves_t BNT-FF1C/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40956852534106775, method='bisection', errormsg=None, context_dct=None) full_result [ 1.65076926e-07 -6.76373020e-08]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4054.529791408447, method='bisection', errormsg=None, context_dct=None) full_result [-1.31113473e-03  3.20131221e-07]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4027.34045123578, method='bisection', errormsg=None, context_dct=None) full_result [-7.09732499e-04 -7.77050445e-07]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9994682546420484, method='bisection', errormsg=None, context_dct=None) full_result [-0.00151062  0.00150299]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9993895090795277, method='bisection', errormsg=None, context_dct=None) full_result [-4.89787199e-05 -2.38863403e-01]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9996477810760712, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00054311 -0.04411559]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25860.496138908864, method='bisection', errormsg=None, context_dct=None) full_result [ 1.13908882e-13 -2.94312485e-09]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25958.88738935483, method='bisection', errormsg=None, context_dct=None) full_result [ 1.04023457e-10 -2.70083547e-06]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0005488018089181, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00167465 -0.00167561]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0006773070202648, method='bisection', errormsg=None, context_dct=None) full_result [ 4.02629375e-05 -4.02927399e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1642.5356619969218, method='bisection', errormsg=None, context_dct=None) full_result [-6.5920176e-09  1.0818243e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1642.2054156236097, method='bisection', errormsg=None, context_dct=None) full_result [ 5.18048182e-09 -8.50856304e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.2158188881624, method='bisection', errormsg=None, context_dct=None) full_result [-3.64934749e-11  6.00703061e-08]
# [PairOptimizer.optimize] curves_t CRV-cd52/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.5128121576444096, method='bisection', errormsg=None, context_dct=None) full_result [ 8.79936124e-11 -6.93504009e-01]
# [PairOptimizer.optimize] curves_t CRV-cd52/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.47848668347779655, method='bisection', errormsg=None, context_dct=None) full_result [ 1.90603089e-12 -9.12159237e-13]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.637151483858, method='bisection', errormsg=None, context_dct=None) full_result [ 2.04153607e-08 -5.50687291e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1652.6435722541178, method='bisection', errormsg=None, context_dct=None) full_result [-9.33941813e-12 -2.83163575e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4054.522266683849, method='bisection', errormsg=None, context_dct=None) full_result [-2.96278557e-11 -5.31602944e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/BNT-FF1C
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=4027.3389732416063, method='bisection', errormsg=None, context_dct=None) full_result [-4.36228831e-10 -2.85833290e+00]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.790406759966878, method='bisection', errormsg=None, context_dct=None) full_result [-1.43223588e-06 -5.19212335e-08]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.812775147298701, method='bisection', errormsg=None, context_dct=None) full_result [ 7.43556713e-07 -1.17917498e-05]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.817111774588557, method='bisection', errormsg=None, context_dct=None) full_result [-5.19674970e-10  4.03588274e-11]
# [PairOptimizer.optimize] curves_t WBTC-C599/WETH-6Cc2
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=15.786713069892642, method='bisection', errormsg=None, context_dct=None) full_result [-1.66444079e-06 -1.33994035e-07]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.0887576656314, method='bisection', errormsg=None, context_dct=None) full_result [ 4.21567847e-09 -1.42522359e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# 2023-09-20 18:24:04,010 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:04,035 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:04,061 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:04,163 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:04,170 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# 2023-09-20 18:24:04,178 [fastlane:ERROR] - [TODO CLEAN UP]list index out of range
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.0887576656314, method='bisection', errormsg=None, context_dct=None) full_result [ 4.21567847e-09 -1.42522359e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.9470071390738, method='bisection', errormsg=None, context_dct=None) full_result [-5.89639448e-13 -1.08224203e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.9470071390738, method='bisection', errormsg=None, context_dct=None) full_result [-5.89639448e-13 -1.08224203e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.4033940136069, method='bisection', errormsg=None, context_dct=None) full_result [ 4.26534763e-09 -1.41685278e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/DAI-1d0F
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.4033940136069, method='bisection', errormsg=None, context_dct=None) full_result [ 4.26534763e-09 -1.41685278e+00]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1642.5356619969218, method='bisection', errormsg=None, context_dct=None) full_result [-6.5920176e-09  1.0818243e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1642.2054156236097, method='bisection', errormsg=None, context_dct=None) full_result [ 5.18048182e-09 -8.50856304e-06]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDT-1ec7
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1654.2158188881624, method='bisection', errormsg=None, context_dct=None) full_result [-3.64934749e-11  6.00703061e-08]
# [PairOptimizer.optimize] curves_t BNT-FF1C/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.40894531356880626, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00000000e+00 -5.82076609e-11]
# [PairOptimizer.optimize] curves_t BNT-FF1C/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.4086633555055692, method='bisection', errormsg=None, context_dct=None) full_result [-1.66706741e-07  6.82193786e-08]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25894.125440594566, method='bisection', errormsg=None, context_dct=None) full_result [-4.25562189e-05  7.28294253e-07]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=26221.377901962558, method='bisection', errormsg=None, context_dct=None) full_result [-3.77166493e-05  3.39932740e-08]
# [PairOptimizer.optimize] curves_t WBTC-C599/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=25947.264438634636, method='bisection', errormsg=None, context_dct=None) full_result [-4.17604274e-05  1.49533153e-05]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0000297312508728, method='bisection', errormsg=None, context_dct=None) full_result [-0.0423584  0.0423584]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0026901251167768, method='bisection', errormsg=None, context_dct=None) full_result [-5.05640273e-05  1.74622983e-10]
# [PairOptimizer.optimize] curves_t DAI-1d0F/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1.0004247950329712, method='bisection', errormsg=None, context_dct=None) full_result [ 0.00736237 -0.00736237]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9994682546420484, method='bisection', errormsg=None, context_dct=None) full_result [-0.00151062  0.00150299]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9993895100725572, method='bisection', errormsg=None, context_dct=None) full_result [-2.39100285e-01  4.19931021e-05]
# [PairOptimizer.optimize] curves_t USDT-1ec7/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=0.9996477811013805, method='bisection', errormsg=None, context_dct=None) full_result [-4.35143951e-02 -7.33835623e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1641.6372358260983, method='bisection', errormsg=None, context_dct=None) full_result [-3.35446311e-03 -2.80184399e-05]
# [PairOptimizer.optimize] curves_t WETH-6Cc2/USDC-eB48
# [PairOptimizer.optimize] p_optimal OptimizerBase.SimpleResult(result=1652.6462448793209, method='bisection', errormsg=None, context_dct=None) full_result [-1.71339668e-03  5.45598141e-07]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-8f368a583675> in <module>
#     124 ]
#     125 assert arb_finder.__name__ == "FindArbitrageMultiPairwise", f"[NBTest_50_TestBancorV2] Expected arb_finder class name name = FindArbitrageMultiPairwise, found {arb_finder.__name__}"
# --> 126 assert len(r) == 41, f"[NBTest_50_TestBancorV2] Expected 41 arb opps, found {len(r)}"
#     127 assert len(arb_with_bancor_v2) == 4, f"[NBTest_50_TestBancorV2] Expected 4 arb opps with Bancor V2 pools, found {len(arb_with_bancor_v2)}"
#     128 assert encoded_trade_instructions[0].amtin * 10 ** 18 == flashloan_amount, f"[NBTest_50_TestBancorV2] First trade in should match flashloan amount"
#
# AssertionError: [NBTest_50_TestBancorV2] Expected 41 arb opps, found 46
