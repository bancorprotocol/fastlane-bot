# %%
from fastlane_bot import Config, ConfigDB, ConfigNetwork, ConfigProvider, Bot
from web3 import Web3
from fastlane_bot.data.abi import CARBON_CONTROLLER_ABI

print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(Config))
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(Bot))
from fastlane_bot.testing import *

from fastlane_bot import __VERSION__
require("2.0", __VERSION__)
# Out:
# Config v1.0-BETA8 (01/May 2023)
# CarbonBot v2.0-BETA4 (30/Apr/2023)
# imported m, np, pd, plt, os, sys, decimal; defined iseq, raises, require
# Version = 2.0-BETA4 [requirements >= 2.0 is met]

# %% [markdown]
# # BOT TEMPLATE Tenderly [NBTest010b]

# %% [markdown]
# ## Tenderly shell commands [NOTEST]
#
# note: the ! commands must be commented out when tests are created

# %%
C_nw = ConfigNetwork.new(network=ConfigNetwork.NETWORK_TENDERLY)
c1, c2 = C_nw.shellcommand().splitlines()

# %%
print(c1)
#!{c1}
# Out:
# brownie networks delete tenderly

# %%
print(c2)
#!{c2}
# Out:
# brownie networks add "Ethereum" "tenderly" host=https://rpc.tenderly.co/fork/c0d1f990-c095-476f-80a9-72ac65092aae chainid=1

# %% [markdown]
# ## Tenderly Configuration

# %% [markdown]
# ### Shell commands
#
# Those shell commands need to be run before being able to connect to tenderly

# %%
C_nw = ConfigNetwork.new(network=ConfigNetwork.NETWORK_TENDERLY)
c1, c2 = C_nw.shellcommand().splitlines()
assert c2 == 'brownie networks add "Ethereum" "tenderly" host=https://rpc.tenderly.co/fork/c0d1f990-c095-476f-80a9-72ac65092aae chainid=1'
assert c1 == 'brownie networks delete tenderly'

# %% [markdown]
# ### Connection proper

# %%
C = Config.new(config=Config.CONFIG_TENDERLY)
assert C.DATABASE == C.DATABASE_POSTGRES
assert C.POSTGRES_DB == "tenderly"
assert C.NETWORK == C.NETWORK_TENDERLY
assert C.PROVIDER == C.PROVIDER_TENDERLY
assert C.w3.__class__.__name__ == "Web3"
assert C.w3.isConnected()
#assert C.w3.provider.endpoint_uri.startswith("https://rpc.tenderly.co/fork/")

# %% [markdown]
# ## Tests that can fail [NOTEST]
#
# for some reason they work in a notebook but fail as tests

# %%
C = Config.new(config=Config.CONFIG_TENDERLY)
assert C.DATABASE == C.DATABASE_POSTGRES
assert C.POSTGRES_DB == "tenderly"
assert C.NETWORK == C.NETWORK_TENDERLY
assert C.PROVIDER == C.PROVIDER_TENDERLY
assert C.w3.__class__.__name__ == "Web3"
assert C.w3.isConnected()
assert C.w3.provider.endpoint_uri.startswith("https://rpc.tenderly.co/fork/")

# %%
mainnet_w3 = Web3(Web3.HTTPProvider(f"https://eth-mainnet.alchemyapi.io/v2/{os.environ.get('WEB3_ALCHEMY_PROJECT_ID')}"))
assert mainnet_w3.eth.blockNumber != C.w3.eth.block_number
print(f"Mainnet block = {mainnet_w3.eth.block_number}, Tenderly block = {C.w3.eth.block_number}")
CARBON_CONTROLLER = C.w3.eth.contract(address="0xC537e898CD774e2dCBa3B14Ea6f34C93d5eA45e1", abi=CARBON_CONTROLLER_ABI)
fee = CARBON_CONTROLLER.caller.tradingFeePPM()
assert type(fee) == int
# Out:
# Mainnet block = 17167780, Tenderly block = 17067512

# %%
C_nw = ConfigNetwork.new(network=ConfigNetwork.NETWORK_TENDERLY)
C_db = ConfigDB.new(db=ConfigDB.DATABASE_POSTGRES)
C_pr = ConfigProvider.new(network=C_nw)
C = Config(db = C_db, network = C_nw, provider = C_pr)
C
# Out:
# Config(network=_ConfigNetworkTenderly(), db=_ConfigDBPostgres(), logger=_ConfigLoggerDefault(), provider=_ConfigProviderTenderly())

# %%
bot = Bot(ConfigObj=C)
# Out:
# Using default database url: postgresql://postgres:b2742bade1f3a271c55eef069e2f19903aa0740c@localhost/mainnet
# 2023-05-01 19:33:22,021 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)
# 2023-05-01 19:33:22,021 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)
# 2023-05-01 19:33:22,021 [fastlane:INFO] - Database: Engine(postgresql://postgres:***@localhost/mainnet)

# %% [markdown]
# ## Bot update [NOTEST]

# %%
help(bot.update)
# Out:
# Help on method update in module fastlane_bot.bot:
#
# update(udtype=None, *, drop_tables=False) method of fastlane_bot.bot.CarbonBot instance
#     convenience access to the db.update methods
#
#     :udtype:            UDTYPE_FROM_CONTRACTS or UDTYPE_FROM_EVENTS
#     :drop_tables:       if True, drops all tables before updating

# %%
bot.update(drop_tables=False)
# Out:
# 2023-05-01 19:33:32,302 [fastlane:INFO] - [model_managers.Token] Created token: BNT-FF1C
# 2023-05-01 19:33:32,302 [fastlane:INFO] - [model_managers.Token] Created token: BNT-FF1C
# 2023-05-01 19:33:32,302 [fastlane:INFO] - [model_managers.Token] Created token: BNT-FF1C
# 2023-05-01 19:33:33,812 [fastlane:INFO] - [model_managers.Token] Created token: DEXE-Cbd6
# 2023-05-01 19:33:33,812 [fastlane:INFO] - [model_managers.Token] Created token: DEXE-Cbd6
# 2023-05-01 19:33:33,812 [fastlane:INFO] - [model_managers.Token] Created token: DEXE-Cbd6
# 2023-05-01 19:33:34,052 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:33:34,052 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:33:34,052 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:33:34,264 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:33:34,264 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:33:34,264 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DEXE-Cbd6
# 2023-05-01 19:33:36,455 [fastlane:INFO] - [model_managers.Token] Created token: COMP-6888
# 2023-05-01 19:33:36,455 [fastlane:INFO] - [model_managers.Token] Created token: COMP-6888
# 2023-05-01 19:33:36,455 [fastlane:INFO] - [model_managers.Token] Created token: COMP-6888
# 2023-05-01 19:33:36,709 [fastlane:INFO] - [model_managers.Pair] Created pair: COMP-6888/BNT-FF1C
# 2023-05-01 19:33:36,709 [fastlane:INFO] - [model_managers.Pair] Created pair: COMP-6888/BNT-FF1C
# 2023-05-01 19:33:36,709 [fastlane:INFO] - [model_managers.Pair] Created pair: COMP-6888/BNT-FF1C
# 2023-05-01 19:33:36,905 [fastlane:INFO] - [model_managers.Pool] Created pool: COMP-6888/BNT-FF1C
# 2023-05-01 19:33:36,905 [fastlane:INFO] - [model_managers.Pool] Created pool: COMP-6888/BNT-FF1C
# 2023-05-01 19:33:36,905 [fastlane:INFO] - [model_managers.Pool] Created pool: COMP-6888/BNT-FF1C
# 2023-05-01 19:33:39,261 [fastlane:INFO] - [model_managers.Token] Created token: COT-9ff8
# 2023-05-01 19:33:39,261 [fastlane:INFO] - [model_managers.Token] Created token: COT-9ff8
# 2023-05-01 19:33:39,261 [fastlane:INFO] - [model_managers.Token] Created token: COT-9ff8
# 2023-05-01 19:33:39,483 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/COT-9ff8
# 2023-05-01 19:33:39,483 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/COT-9ff8
# 2023-05-01 19:33:39,483 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/COT-9ff8
# 2023-05-01 19:33:39,680 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/COT-9ff8
# 2023-05-01 19:33:39,680 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/COT-9ff8
# 2023-05-01 19:33:39,680 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/COT-9ff8
# 2023-05-01 19:33:42,193 [fastlane:INFO] - [model_managers.Token] Created token: DAO-09Ad
# 2023-05-01 19:33:42,193 [fastlane:INFO] - [model_managers.Token] Created token: DAO-09Ad
# 2023-05-01 19:33:42,193 [fastlane:INFO] - [model_managers.Token] Created token: DAO-09Ad
# 2023-05-01 19:33:42,423 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DAO-09Ad
# 2023-05-01 19:33:42,423 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DAO-09Ad
# 2023-05-01 19:33:42,423 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DAO-09Ad
# 2023-05-01 19:33:42,626 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DAO-09Ad
# 2023-05-01 19:33:42,626 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DAO-09Ad
# 2023-05-01 19:33:42,626 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DAO-09Ad
# 2023-05-01 19:33:45,131 [fastlane:INFO] - [model_managers.Token] Created token: DAPP-1649
# 2023-05-01 19:33:45,131 [fastlane:INFO] - [model_managers.Token] Created token: DAPP-1649
# 2023-05-01 19:33:45,131 [fastlane:INFO] - [model_managers.Token] Created token: DAPP-1649
# 2023-05-01 19:33:45,367 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DAPP-1649
# 2023-05-01 19:33:45,367 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DAPP-1649
# 2023-05-01 19:33:45,367 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DAPP-1649
# 2023-05-01 19:33:45,572 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DAPP-1649
# 2023-05-01 19:33:45,572 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DAPP-1649
# 2023-05-01 19:33:45,572 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DAPP-1649
# 2023-05-01 19:33:47,841 [fastlane:INFO] - [model_managers.Token] Created token: BORING-92CA
# 2023-05-01 19:33:47,841 [fastlane:INFO] - [model_managers.Token] Created token: BORING-92CA
# 2023-05-01 19:33:47,841 [fastlane:INFO] - [model_managers.Token] Created token: BORING-92CA
# 2023-05-01 19:33:48,073 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/BORING-92CA
# 2023-05-01 19:33:48,073 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/BORING-92CA
# 2023-05-01 19:33:48,073 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/BORING-92CA
# 2023-05-01 19:33:48,275 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/BORING-92CA
# 2023-05-01 19:33:48,275 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/BORING-92CA
# 2023-05-01 19:33:48,275 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/BORING-92CA
# 2023-05-01 19:33:50,541 [fastlane:INFO] - [model_managers.Token] Created token: DDX-Ed3A
# 2023-05-01 19:33:50,541 [fastlane:INFO] - [model_managers.Token] Created token: DDX-Ed3A
# 2023-05-01 19:33:50,541 [fastlane:INFO] - [model_managers.Token] Created token: DDX-Ed3A
# 2023-05-01 19:33:50,772 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DDX-Ed3A
# 2023-05-01 19:33:50,772 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DDX-Ed3A
# 2023-05-01 19:33:50,772 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DDX-Ed3A
# 2023-05-01 19:33:50,972 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DDX-Ed3A
# 2023-05-01 19:33:50,972 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DDX-Ed3A
# 2023-05-01 19:33:50,972 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DDX-Ed3A
# 2023-05-01 19:33:53,227 [fastlane:INFO] - [model_managers.Token] Created token: eRSDL-D3A6
# 2023-05-01 19:33:53,227 [fastlane:INFO] - [model_managers.Token] Created token: eRSDL-D3A6
# 2023-05-01 19:33:53,227 [fastlane:INFO] - [model_managers.Token] Created token: eRSDL-D3A6
# 2023-05-01 19:33:53,476 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/eRSDL-D3A6
# 2023-05-01 19:33:53,476 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/eRSDL-D3A6
# 2023-05-01 19:33:53,476 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/eRSDL-D3A6
# 2023-05-01 19:33:53,686 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/eRSDL-D3A6
# 2023-05-01 19:33:53,686 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/eRSDL-D3A6
# 2023-05-01 19:33:53,686 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/eRSDL-D3A6
# 2023-05-01 19:33:56,140 [fastlane:INFO] - [model_managers.Token] Created token: DIP-cD83
# 2023-05-01 19:33:56,140 [fastlane:INFO] - [model_managers.Token] Created token: DIP-cD83
# 2023-05-01 19:33:56,140 [fastlane:INFO] - [model_managers.Token] Created token: DIP-cD83
# 2023-05-01 19:33:56,365 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DIP-cD83
# 2023-05-01 19:33:56,365 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DIP-cD83
# 2023-05-01 19:33:56,365 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/DIP-cD83
# 2023-05-01 19:33:56,560 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DIP-cD83
# 2023-05-01 19:33:56,560 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/DIP-cD83
# 2023-05-01 19:33:56,560 [fastlane:INFO] - [model_managers.Pool] Created pool: BNT-FF1C/
[fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0x1337DEF16F9B486fAEd0293eb623Dc8395dFE46a, unsupported operand type(s) for |: 'dict' and 'dict'
# 2023-05-01 19:34:57,916 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0x1337DEF16F9B486fAEd0293eb623Dc8395dFE46a, unsupported operand type(s) for |: 'dict' and 'dict'
# 2023-05-01 19:34:57,925 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0x1337DEF16F9B486fAEd0293eb623Dc8395dFE46a on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:34:57,925 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0x1337DEF16F9B486fAEd0293eb623Dc8395dFE46a on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:34:57,925 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0x1337DEF16F9B486fAEd0293eb623Dc8395dFE46a on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:34:59,355 [fastlane:INFO] - [model_managers.Token] Created token: AUC-5663
# 2023-05-01 19:34:59,355 [fastlane:INFO] - [model_managers.Token] Created token: AUC-5663
# 2023-05-01 19:34:59,355 [fastlane:INFO] - [model_managers.Token] Created token: AUC-5663
# 2023-05-01 19:34:59,587 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/AUC-5663
# 2023-05-01 19:34:59,587 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/AUC-5663
# 2023-05-01 19:34:59,587 [fastlane:INFO] - [model_managers.Pair] Created pair: BNT-FF1C/AUC-5663
# 2023-05-01 19:35:00,165 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0xc12d099be31567add4e4e4d0D45691C3F58f5663, unsupported operand type(s) for |: 'dict' and 'dict'
# 2023-05-01 19:35:00,165 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0xc12d099be31567add4e4e4d0D45691C3F58f5663, unsupported operand type(s) for |: 'dict' and 'dict'
# 2023-05-01 19:35:00,165 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0xc12d099be31567add4e4e4d0D45691C3F58f5663, unsupported operand type(s) for |: 'dict' and 'dict'
# 2023-05-01 19:35:00,173 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xc12d099be31567add4e4e4d0D45691C3F58f5663 on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:35:00,173 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xc12d099be31567add4e4e4d0D45691C3F58f5663 on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:35:00,173 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xc12d099be31567add4e4e4d0D45691C3F58f5663 on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:35:00,782 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0xFe459828c90c0BA4bC8b42F5C5D44F316700B430, unsupported operand type(s) for |: 'dict' and 'dict'
# 2023-05-01 19:35:00,782 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0xFe459828c90c0BA4bC8b42F5C5D44F316700B430, unsupported operand type(s) for |: 'dict' and 'dict'
# 2023-05-01 19:35:00,782 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0xFe459828c90c0BA4bC8b42F5C5D44F316700B430, unsupported operand type(s) for |: 'dict' and 'dict'
# 2023-05-01 19:35:00,787 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xFe459828c90c0BA4bC8b42F5C5D44F316700B430 on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:35:00,787 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xFe459828c90c0BA4bC8b42F5C5D44F316700B430 on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:35:00,787 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0xFe459828c90c0BA4bC8b42F5C5D44F316700B430 on bancor_v3, Class 'builtins.NoneType' is not mapped, continuing...
# 2023-05-01 19:35:01,394 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0xBC19712FEB3a26080eBf6f2F7849b417FdD792CA, unsupported operand type(s) for |: 'dict' and 'dict'
# 2023-05-01 19:35:01,394 [fastlane:WARNING] - [create_pool] Failed to create pool for bancor_v3, 0xBC19712FEB3a26080eBf6f2F7849b417FdD792CA, unsupported operand type(s) for |: 'dict' and 'dict'
# ...
# FROM pools
# WHERE pools.exchange_name = %(exchange_name_1)s AND pools.address = %(address_1)s
#  LIMIT %(param_1)s]
# [parameters: {'exchange_name_1': 'bancor_v3', 'address_1': '0x1776e1F26f98b1A5dF9cD347953a26dd3Cb46671', 'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85), continuing...
# 2023-05-01 19:35:36,500 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0x1776e1F26f98b1A5dF9cD347953a26dd3Cb46671 on bancor_v3, (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT pools.id AS pools_id, pools.cid AS pools_cid, pools.last_updated AS pools_last_updated, pools.last_updated_block AS pools_last_updated_block, pools.descr AS pools_descr, pools.pair_name AS pools_pair_name, pools.exchange_name AS pools_exchange_name, pools.fee AS pools_fee, pools.fee_float AS pools_fee_float, pools.tkn0_balance AS pools_tkn0_balance, pools.tkn1_balance AS pools_tkn1_balance, pools.z_0 AS pools_z_0, pools.y_0 AS pools_y_0, pools."A_0" AS "pools_A_0", pools."B_0" AS "pools_B_0", pools.z_1 AS pools_z_1, pools.y_1 AS pools_y_1, pools."A_1" AS "pools_A_1", pools."B_1" AS "pools_B_1", pools.sqrt_price_q96 AS pools_sqrt_price_q96, pools.tick AS pools_tick, pools.tick_spacing AS pools_tick_spacing, pools.liquidity AS pools_liquidity, pools.address AS pools_address, pools.anchor AS pools_anchor
# FROM pools
# WHERE pools.exchange_name = %(exchange_name_1)s AND pools.address = %(address_1)s
#  LIMIT %(param_1)s]
# [parameters: {'exchange_name_1': 'bancor_v3', 'address_1': '0x1776e1F26f98b1A5dF9cD347953a26dd3Cb46671', 'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85), continuing...
# 2023-05-01 19:35:36,500 [fastlane:WARNING] - [managers.create_or_update_pool_with_multicall] Error updating pool 0x1776e1F26f98b1A5dF9cD347953a26dd3Cb46671 on bancor_v3, (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT pools.id AS pools_id, pools.cid AS pools_cid, pools.last_updated AS pools_last_updated, pools.last_updated_block AS pools_last_updated_block, pools.descr AS pools_descr, pools.pair_name AS pools_pair_name, pools.exchange_name AS pools_exchange_name, pools.fee AS pools_fee, pools.fee_float AS pools_fee_float, pools.tkn0_balance AS pools_tkn0_balance, pools.tkn1_balance AS pools_tkn1_balance, pools.z_0 AS pools_z_0, pools.y_0 AS pools_y_0, pools."A_0" AS "pools_A_0", pools."B_0" AS "pools_B_0", pools.z_1 AS pools_z_1, pools.y_1 AS pools_y_1, pools."A_1" AS "pools_A_1", pools."B_1" AS "pools_B_1", pools.sqrt_price_q96 AS pools_sqrt_price_q96, pools.tick AS pools_tick, pools.tick_spacing AS pools_tick_spacing, pools.liquidity AS pools_liquidity, pools.address AS pools_address, pools.anchor AS pools_anchor
# FROM pools
# WHERE pools.exchange_name = %(exchange_name_1)s AND pools.address = %(address_1)s
#  LIMIT %(param_1)s]
# [parameters: {'exchange_name_1': 'bancor_v3', 'address_1': '0x1776e1F26f98b1A5dF9cD347953a26dd3Cb46671', 'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85), continuing...
# 2023-05-01 19:35:36,533 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool bancor_v3 0x8798249c2E607446EfB7Ad49eC89dD1865Ff4272 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,533 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool bancor_v3 0x8798249c2E607446EfB7Ad49eC89dD1865Ff4272 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,533 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool bancor_v3 0x8798249c2E607446EfB7Ad49eC89dD1865Ff4272 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,572 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool uniswap_v2 0x718Dd8B743ea19d71BDb4Cb48BB984b73a65cE06 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,572 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool uniswap_v2 0x718Dd8B743ea19d71BDb4Cb48BB984b73a65cE06 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,572 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool uniswap_v2 0x718Dd8B743ea19d71BDb4Cb48BB984b73a65cE06 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,614 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool uniswap_v3 0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,614 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool uniswap_v3 0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,614 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool uniswap_v3 0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,652 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool sushiswap_v2 0x58Dc5a51fE44589BEb22E8CE67720B5BC5378009 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,652 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool sushiswap_v2 0x58Dc5a51fE44589BEb22E8CE67720B5BC5378009 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,652 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool sushiswap_v2 0x58Dc5a51fE44589BEb22E8CE67720B5BC5378009 [(psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT max(pools.id) AS max_1
# FROM pools
#  LIMIT %(param_1)s]
# [parameters: {'param_1': 1}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)]
# 2023-05-01 19:35:36,655 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool carbon_v1 0x58Dc5a51fE44589BEb22E8CE67720B5BC5378009 ['carbon_v1']
# 2023-05-01 19:35:36,655 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool carbon_v1 0x58Dc5a51fE44589BEb22E8CE67720B5BC5378009 ['carbon_v1']
# 2023-05-01 19:35:36,655 [fastlane:ERROR] - [manager.create_pools_from_contracts] Error creating pool carbon_v1 0x58Dc5a51fE44589BEb22E8CE67720B5BC5378009 ['carbon_v1']
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block
#
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-13-f5def29c8d00> in <module>
# ----> 1 bot.update(drop_tables=True)
#
# ~/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/bot.py in update(self, udtype, drop_tables)
#     183
#     184         if udtype == self.UDTYPE_FROM_CONTRACTS:
# --> 185             return self.db.update_pools_from_contracts()
#     186         elif udtype == self.UDTYPE_FROM_EVENTS:
#     187             return self.db.update_pools_from_events()
#
# ~/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/db/manager.py in update_pools_from_contracts(self)
#      91
#      92         for exchange in self.ConfigObj.SUPPORTED_EXCHANGES:
# ---> 93             pools = self.get_pools_from_exchange(exchange)
#      94             for pool in pools:
#      95                 if pool.exchange_name == exchange:
#
# ~/REPOES/Bancor/ArbBot/resources/NBTest/fastlane_bot/db/manager.py in get_pools_from_exchange(self, exchange)
#     469             The pools
#     470         """
# --> 471         return self.session.query(models.Pool).filter(models.Pool.exchange_name == exchange).all()
#     472
#     473     def create_pools_from_contracts(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/query.py in all(self)
#    2683                 :ref:`faq_query_deduplicating`
#    2684         """
# -> 2685         return self._iter().all()
#    2686
#    2687     @_generative
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/query.py in _iter(self)
#    2818
#    2819         statement = self._statement_20()
# -> 2820         result = self.session.execute(
#    2821             statement,
#    2822             params,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/orm/session.py in execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, **kw)
#    1668
#    1669         conn = self._connection_for_bind(bind, close_with_result=True)
# -> 1670         result = conn._execute_20(statement, params or {}, execution_options)
#    1671
#    1672         if compile_state_cls:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_20(self, statement, parameters, execution_options)
#    1518             )
#    1519         else:
# -> 1520             return meth(self, args_10style, kwargs_10style, execution_options)
#    1521
#    1522     def exec_driver_sql(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1703                             break
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#    1707                     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     690
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#     694     def do_execute_no_params(self, cursor, statement, context=None):
#
# InternalError: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: SELECT pools.id AS pools_id, pools.cid AS pools_cid, pools.last_updated AS pools_last_updated, pools.last_updated_block AS pools_last_updated_block, pools.descr AS pools_descr, pools.pair_name AS pools_pair_name, pools.exchange_name AS pools_exchange_name, pools.fee AS pools_fee, pools.fee_float AS pools_fee_float, pools.tkn0_balance AS pools_tkn0_balance, pools.tkn1_balance AS pools_tkn1_balance, pools.z_0 AS pools_z_0, pools.y_0 AS pools_y_0, pools."A_0" AS "pools_A_0", pools."B_0" AS "pools_B_0", pools.z_1 AS pools_z_1, pools.y_1 AS pools_y_1, pools."A_1" AS "pools_A_1", pools."B_1" AS "pools_B_1", pools.sqrt_price_q96 AS pools_sqrt_price_q96, pools.tick AS pools_tick, pools.tick_spacing AS pools_tick_spacing, pools.liquidity AS pools_liquidity, pools.address AS pools_address, pools.anchor AS pools_anchor
# FROM pools
# WHERE pools.exchange_name = %(exchange_name_1)s]
# [parameters: {'exchange_name_1': 'bancor_v2'}]
# (Background on this error at: http://sqlalche.me/e/14/2j85)
