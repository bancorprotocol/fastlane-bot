# %%
import requests

def get_top_n_pools_for_exchange(exchange_name: str, top_n: int = 200) -> list:
    """
    Fetches the top 5 pools from the given platform.

    Parameters
    ----------
    exchange_name : str
        The exchange_name to fetch the top 5 pools from. Choose from 'uniswap_v2', 'uniswap_v3', or 'sushiswap'.
    top_n : int, optional
        The number of pools to fetch, by default 5

    Returns
    -------
    list
        A list of the top 5 pools from the given platform.
    """
    if exchange_name not in ["uniswap_v2", "uniswap_v3", "sushiswap"]:
        raise ValueError("Invalid platform. Choose from 'uniswap_v2', 'uniswap_v3', or 'sushiswap'.")

    if exchange_name == "uniswap_v2":
        url = "https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v2"
        query = """
        {
          pairs(first: top_n, orderBy: reserveUSD, orderDirection: desc) {
            id
            token0 {
              symbol
              id
            }
            token1 {
              symbol
              id
            }
          }
        }
        """.replace("top_n", str(top_n))
    elif exchange_name == "uniswap_v3":
        url = "https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3"
        query = """
        {
          pools(first: top_n, orderBy: liquidity, orderDirection: desc) {
            id
            token0 {
              symbol
              id
            }
            token1 {
              symbol
              id
            }
          }
        }
        """.replace("top_n", str(top_n))
    elif exchange_name == "sushiswap":
        url = "https://api.thegraph.com/subgraphs/name/sushiswap/exchange"
        query = """
        {
          pairs(first: top_n, orderBy: reserveUSD, orderDirection: desc) {
            id
            token0 {
              symbol
              id
            }
            token1 {
              symbol
              id
            }
          }
        }
        """.replace("top_n", str(top_n))

    response = requests.post(url, json={'query': query})
    data = response.json()

    if "errors" in data:
        raise Exception("Error in fetching data from TheGraph API")

    pairs = data["data"]["pairs"] if exchange_name != "uniswap_v3" else data["data"]["pools"]

    pair_info = []
    for pair in pairs:
        pool_address = pair["id"]
        tkn0_key = f"{pair['token0']['symbol']}-{pair['token0']['id'][-4:]}"
        tkn1_key = f"{pair['token1']['symbol']}-{pair['token1']['id'][-4:]}"
        pair_name = f"{tkn0_key}/{tkn1_key}"
        pair_info.append({"pair_name": pair_name, "pool_address": pool_address})

    return pair_info

top_5_uniswap_v2_pairs = get_top_n_pools_for_exchange("uniswap_v2")
top_5_uniswap_v3_pairs = get_top_n_pools_for_exchange("uniswap_v3")
top_5_sushiswap_pairs = get_top_n_pools_for_exchange("sushiswap")



print("Top 5 Uniswap v2 pairs:", top_5_uniswap_v2_pairs)
print("Top 5 Uniswap v3 pairs:", top_5_uniswap_v3_pairs)
print("Top 5 SushiSwap pairs:", top_5_sushiswap_pairs)
# Out:
# Top 5 Uniswap v2 pairs: [{'pair_name': 'UETH-80b3/ULCK-e629', 'pool_address': '0xe6c78983b07a07e0523b57e18aa23d3ae2519e05'}, {'pair_name': 'WISE-5bd6/WETH-6cc2', 'pool_address': '0x21b8065d10f73ee2e260e5b47d3344d3ced7596e'}, {'pair_name': 'USDC-eb48/WETH-6cc2', 'pool_address': '0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc'}, {'pair_name': 'WETH-6cc2/USDT-1ec7', 'pool_address': '0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852'}, {'pair_name': 'DELTA-20ef/WETH-6cc2', 'pool_address': '0x7d7e813082ef6c143277c71786e5be626ec77b20'}, {'pair_name': 'FNK-48ad/USDT-1ec7', 'pool_address': '0x61b62c5d56ccd158a38367ef2f539668a06356ab'}, {'pair_name': 'RK:ETH-aa96/ROOT-570e', 'pool_address': '0x0617d5ffb29c03ac35f1863b8a50ce1b52d446f6'}, {'pair_name': 'DAI-1d0f/USDC-eb48', 'pool_address': '0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5'}, {'pair_name': 'USDC-eb48/USDT-1ec7', 'pool_address': '0x3041cbd36888becc7bbcbc0045e3b1f144466f5f'}, {'pair_name': 'ETH2POS-1df9/DC-802c', 'pool_address': '0xe2f95dae6c5763c357447fe1ffb3f2a884bdc0b5'}, {'pair_name': 'M2-d15c/wPE-881b', 'pool_address': '0x9816f26f43c4c02df0daae1a0ba6a4dcd30b8ab7'}, {'pair_name': 'DAI-1d0f/WETH-6cc2', 'pool_address': '0xa478c2975ab1ea89e8196811f51a7b7ade33eb11'}, {'pair_name': 'FXS-64d0/FRAX-b99e', 'pool_address': '0xe1573b9d29e2183b1af0e743dc2754979a40d237'}, {'pair_name': 'DBL-8d29/BLUE-0606', 'pool_address': '0xc86881ef494b049fe3e624ae6fdf542f58ab1931'}, {'pair_name': 'HANU-bcc0/MIA-ce0b', 'pool_address': '0x48918f57fa7210ea7b20f23da8420e68df3578fe'}, {'pair_name': 'HANU-bcc0/GOJ-679a', 'pool_address': '0x93512394a82d278b9961e3891a59c6dc1c2e4f98'}, {'pair_name': 'XXi-6df2/WETH-6cc2', 'pool_address': '0x0af81cd5d9c124b4859d65697a4cd10ee223746a'}, {'pair_name': 'WETH-6cc2/CAW-e452', 'pool_address': '0x48d20b3e529fb3dd7d91293f80638df582ab2daa'}, {'pair_name': 'MC-e5d6/WETH-6cc2', 'pool_address': '0xccb63225a7b19dcf66717e4d40c9a72b39331d61'}, {'pair_name': 'ELON-60f3/WETH-6cc2', 'pool_address': '0x7b73644935b8e68019ac6356c40661e1bc315860'}, {'pair_name': 'BHNY-0844/wPE-881b', 'pool_address': '0x9ec96dcb54331626b79d8450a3daa9bcfa02e0b0'}, {'pair_name': 'UNI-f984/WETH-6cc2', 'pool_address': '0xd3d2e2692501a5c9ca623199d38826e513033a17'}, {'pair_name': 'vUSD-937a/VOW-46fb', 'pool_address': '0x97be09f2523b39b835da9ea3857cfa1d3c660cbb'}, {'pair_name': 'WBTC-c599/WETH-6cc2', 'pool_address': '0xbb2b8038a1640196fbe3e38816f3e67cba72d940'}, {'pair_name': 'FEI-87ca/TRIBE-212b', 'pool_address': '0x9928e4046d7c6513326ccea028cd3e7a91c7590a'}, {'pair_name': 'PAXG-af78/WETH-6cc2', 'pool_address': '0x9c4fe5ffd9a9fc5678cfbd93aa2d4fd684b67c4c'}, {'pair_name': 'BigSB-b6f6/USDC-eb48', 'pool_address': '0x149148acc3b06b8cc73af3a10e84189243a35925'}, {'pair_name': 'WETH-6cc2/SUPER-0a55', 'pool_address': '0x25647e01bd0967c1b9599fa3521939871d1d0888'}, {'pair_name': 'WAXE-4dfd/WETH-6cc2', 'pool_address': '0x0ee0cb563a52ae1170ac34fbb94c50e89adde4bd'}, {'pair_name': 'WETH-6cc2/FLOKI-6a2e', 'pool_address': '0xca7c2771d248dcbe09eabe0ce57a62e18da178c0'}, {'pair_name': 'UETH-80b3/DAPE-7a06', 'pool_address': '0xf778c77ec3696879cb5ac814984655aefe66d716'}, {'pair_name': 'ULS-03ae/UETH-80b3', 'pool_address': '0x0179d00549b44d3161b9c260815f8a5947a541b3'}, {'pair_name': 'WETH-6cc2/BTT-7957', 'pool_address': '0x2d0ba902badaa82592f0e1c04c71d66cea21d921'}, {'pair_name': 'DG-dede/USDC-eb48', 'pool_address': '0x873056a02255872514f05249d93228d788fe4fb4'}, {'pair_name': 'WOO-5d4b/WETH-6cc2', 'pool_address': '0x6ada49aeccf6e556bb7a35ef0119cc8ca795294a'}, {'pair_name': 'UFO-dc3b/WETH-6cc2', 'pool_address': '0x97e1fcb93ae7267dbafad23f7b9afaa08264cfd8'}, {'pair_name': 'eXRD-9414/USDC-eb48', 'pool_address': '0x684b00a5773679f88598a19976fbeb25a68e9a5f'}, {'pair_name': 'WETH-6cc2/FOX-e52d', 'pool_address': '0x470e8de2ebaef52014a47cb5e6af86884947f08c'}, {'pair_name': 'WETH-6cc2/SAITAMA-27b2', 'pool_address': '0xe3d3551bb608e7665472180a20280630d9e938aa'}, {'pair_name': 'PAXG-af78/USDC-eb48', 'pool_address': '0x6d74443bb2d50785989a7212ebfd3a8db ...
# Top 5 Uniswap v3 pairs: [{'pair_name': 'I-2897/WETH-6cc2', 'pool_address': '0x5d342c10657fd352ceb4d7cd23504580b950fb2f'}, {'pair_name': 'WETH-6cc2/ARTSTIC-b7f9', 'pool_address': '0x623c55ef1c942931380a240d5026af4423f9037d'}, {'pair_name': 'FIND-8e0a/WETH-6cc2', 'pool_address': '0x61a6834c7928cbb03e6ac4d31b8bd1bbf2481894'}, {'pair_name': 'MingBi-9db9/WETH-6cc2', 'pool_address': '0xb0afc043887a7e5f28a5da2e2ad3e2e46244923d'}, {'pair_name': 'HMB-a68a/HMB-4929', 'pool_address': '0x010e3607ee6d9f43a24efe589a9fec74bba101fd'}, {'pair_name': 'XEN-6fb8/XUSD-e7d8', 'pool_address': '0x76764f4f6afed0329e72cf6982d83f877ee9ebae'}, {'pair_name': 'ITO-c5ab/WETH-6cc2', 'pool_address': '0x2e5848efcfac935dd243c9094048ac346e198e1d'}, {'pair_name': 'HVC-51a4/WETH-6cc2', 'pool_address': '0x06bd1af522f43bc270203e96a019b4779195b870'}, {'pair_name': 'OTO-8b56/WETH-6cc2', 'pool_address': '0x18bb49dabec36c29af9450f420e675f46c416042'}, {'pair_name': 'BBA-8eb0/WETH-6cc2', 'pool_address': '0x76ad89d68b81affc636b4b4b23efb426f0150078'}, {'pair_name': 'MASATO-921a/WETH-6cc2', 'pool_address': '0xad76da68a204fe301cc9b1c60f7166db73d35e76'}, {'pair_name': '100MD-fbe6/SHIB-c4ce', 'pool_address': '0x058e136bc597082589d2cf5d0d021e22b6556a9c'}, {'pair_name': 'STFMG-1e39/WETH-6cc2', 'pool_address': '0x2df3f8e466d4924d86c35213dcef8c6955c6813a'}, {'pair_name': 'WETH-6cc2/BDOG-15b5', 'pool_address': '0xedcfece1060e568e10425e95e35b179d5b5a2b5f'}, {'pair_name': 'ADOGE-dec5/WETH-6cc2', 'pool_address': '0x235c74836bf329a8c4172af9d07173f38026a49c'}, {'pair_name': 'RCK-53cc/WETH-6cc2', 'pool_address': '0x7563201511e9e89d2919de06c30250dc97af927b'}, {'pair_name': 'TOS-8153/WTON-bff2', 'pool_address': '0x1c0ce9aaa0c12f53df3b4d8d77b82d6ad343b4e4'}, {'pair_name': 'KNX-9f6b/KNX-7da0', 'pool_address': '0xdfadab25757e97d90d491eaf98e74b4a8f430e97'}, {'pair_name': 'ELON-60f3/carbon-3286', 'pool_address': '0x3a381e03c43938c24fc2ea9a86045c2ca1a94e92'}, {'pair_name': 'DIM-44ac/WETH-6cc2', 'pool_address': '0xfcb8651ec7c8d610c2c19ba6a4a4bf6bc7e08c76'}, {'pair_name': 'STFMG-1e39/STARS-b7f5', 'pool_address': '0x9f7e947239de8db3cd500e1180797b22c0192531'}, {'pair_name': 'ELONINDEX-23d0/ELON-60f3', 'pool_address': '0x86920f1b233ffd2cf359b378b78f708f2c372561'}, {'pair_name': 'PROS-008a/BTT-7957', 'pool_address': '0x8a31e6ac998b497bb4db8c9bbaab6a3fe636605c'}, {'pair_name': 'FAMILY-4798/DAI-1d0f', 'pool_address': '0xf58b9748e838d09ff3ccc20d602321003c516dc2'}, {'pair_name': 'KOCHI-f735/WETH-6cc2', 'pool_address': '0xdab59355190d110f9f71a5f97993511343264db3'}, {'pair_name': 'DAI-1d0f/FRAX-b99e', 'pool_address': '0x97e7d56a0408570ba1a7852de36350f7713906ec'}, {'pair_name': 'WETH-6cc2/USE-b9e1', 'pool_address': '0xd4ffa25b7cbb1c963e95b2876c49606e36b66826'}, {'pair_name': 'Murakami-cde9/WETH-6cc2', 'pool_address': '0xc536deb8d19a3347f5ae088e3ac309cefab6db53'}, {'pair_name': 'ARTS-e2de/HVE2-73f5', 'pool_address': '0x134aef44660609f9220d63f079f739549d650b08'}, {'pair_name': 'CLNR-f992/CLEANER-a514', 'pool_address': '0xb57a06451abc1f8f68387eaa001972d21f1e16d4'}, {'pair_name': 'Metti-4573/WETH-6cc2', 'pool_address': '0x0378304e50fced815abf96f30837c3c61a750c82'}, {'pair_name': 'UMIIE-2d9b/UMIIE2-056f', 'pool_address': '0xa850478adaace4c08fc61de44d8cf3b64f359bec'}, {'pair_name': 'WETH-6cc2/SHIBAGOLD-86de', 'pool_address': '0x0ff3164c4fcb2bebc21cc25ef4bd5743b893f464'}, {'pair_name': 'WVRH-f456/VRH-44b2', 'pool_address': '0xd6a0118a81444969c854bf2cc6731101ff99cd02'}, {'pair_name': 'MOVIE-1769/WETH-6cc2', 'pool_address': '0x47ce13d5c5f16a15ccfe7fc9f2cdc44b0d6d4b84'}, {'pair_name': 'WETH-6cc2/MLD-58d8', 'pool_address': '0x4ceeafbe41095d980d6124078e7db5412de3a23c'}, {'pair_name': 'WOJAK-9aab/PEPE-1933', 'pool_address': '0x0b4cb9d4fb1cee079392bc7cf6417a669f4c2dbd'}, {'pair_name': 'CIV-361d/0NE-f4c2', 'pool_address': '0x27887664e38c04ea151964d1f87dd5fd96aa50ec'}, {'pair_name': 'AKITA-23e6/carbon-3286', 'pool_address': '0xfc9bc741db8694079709007a550de22ad4f37963'}, {'pair_name': 'OGER-8a62/LUNA-1ea9', 'pool_address': '0 ...
# Top 5 SushiSwap pairs: [{'pair_name': 'ILV-ca0e/WETH-6cc2', 'pool_address': '0x6a091a3406e0073c3cd6340122143009adac0eda'}, {'pair_name': 'USDC-eb48/WETH-6cc2', 'pool_address': '0x397ff1542f962076d0bfe58ea045ffa2d347aca0'}, {'pair_name': 'WBTC-c599/WETH-6cc2', 'pool_address': '0xceff51756c56ceffca006cd410b03ffc46dd3a58'}, {'pair_name': 'WETH-6cc2/USDT-1ec7', 'pool_address': '0x06da0fd433c1a5d7a4faa01111c044910a184553'}, {'pair_name': 'UwU-5257/WETH-6cc2', 'pool_address': '0x3e04863dba602713bb5d0edbf7db7c3a9a2b6027'}, {'pair_name': 'SUSHI-0fe2/WETH-6cc2', 'pool_address': '0x795065dcc9f64b5614c407a6efdc400da6221fb0'}, {'pair_name': 'SYN-9f29/WETH-6cc2', 'pool_address': '0x4a86c01d67965f8cb3d0aaa2c655705e64097c31'}, {'pair_name': 'PUNK-232a/WETH-6cc2', 'pool_address': '0x0463a06fbc8bf28b3f120cd1bfc59483f099d332'}, {'pair_name': 'DAI-1d0f/WETH-6cc2', 'pool_address': '0xc3d03e4f041fd4cd388c549ee2a29a9e5075882f'}, {'pair_name': 'DELTA-20ef/WETH-6cc2', 'pool_address': '0x1498bd576454159bb81b5ce532692a8752d163e8'}, {'pair_name': 'MULTI-2df4/WETH-6cc2', 'pool_address': '0x82917fb0dd65b0e5c85eea66e4f5c1ed484bc629'}, {'pair_name': 'TOKE-8c94/WETH-6cc2', 'pool_address': '0xd4e7a6e2d03e4e48dfc27dd3f46df1c176647e38'}, {'pair_name': 'LON-c952/USDT-1ec7', 'pool_address': '0x55d31f68975e446a40a2d02ffa4b0e1bfb233c2f'}, {'pair_name': 'WETH-6cc2/ALCX-c8df', 'pool_address': '0xc3f279090a47e80990fe3a9c30d24cb117ef91a8'}, {'pair_name': 'YFI-d93e/WETH-6cc2', 'pool_address': '0x088ee5007c98a9677165d78dd2109ae4a3d04d0c'}, {'pair_name': 'WETH-6cc2/JPEG-45a3', 'pool_address': '0xdb06a76733528761eda47d356647297bc35a98bd'}, {'pair_name': 'COMP-6888/WETH-6cc2', 'pool_address': '0x31503dcb60119a812fee820bb7042752019f2355'}, {'pair_name': 'FXS-64d0/WETH-6cc2', 'pool_address': '0x61eb53ee427ab4e007d78a9134aacb3101a2dc23'}, {'pair_name': 'WETH-6cc2/USH-ec48', 'pool_address': '0xaaf448d30f01b429fb6e7f9af6a8ff66e694f312'}, {'pair_name': 'WETH-6cc2/FOLD-5921', 'pool_address': '0xa914a9b9e03b6af84f9c6bd2e0e8d27d405695db'}, {'pair_name': 'WETH-6cc2/BTT-7957', 'pool_address': '0xe9cf42bfcd65e342a96fc063304e22db33e236ac'}, {'pair_name': 'DOG-8899/WETH-6cc2', 'pool_address': '0xc96f20099d96b37d7ede66ff9e4de59b9b1065b1'}, {'pair_name': 'NEWO-7d96/USDC-eb48', 'pool_address': '0xc08ed9a9abeabcc53875787573dc32eee5e43513'}, {'pair_name': 'LINK-86ca/WETH-6cc2', 'pool_address': '0xc40d16476380e4037e6b1a2594caf6a6cc8da967'}, {'pair_name': 'SPS-df74/WETH-6cc2', 'pool_address': '0x1b803af96f37ae51fa753e13e1d2e372dfa17791'}, {'pair_name': 'EDEN-1559/WETH-6cc2', 'pool_address': '0x82dbc2673e9640343d263a3c55de49021ad39ae2'}, {'pair_name': 'SPELL-e5f6/WETH-6cc2', 'pool_address': '0xb5de0c3753b6e1b4dba616db82767f17513e6d4e'}, {'pair_name': 'RADAR-4dbe/WETH-6cc2', 'pool_address': '0x559ebe4e206e6b4d50e9bd3008cda7ce640c52cb'}, {'pair_name': 'xSUSHI-4272/WETH-6cc2', 'pool_address': '0x36e2fcccc59e5747ff63a03ea2e5c0c2c14911e7'}, {'pair_name': 'USDC-eb48/QUARTZ-25ef', 'pool_address': '0x1e888882d0f291dd88c5605108c72d414f29d460'}, {'pair_name': 'THOR-8044/WETH-6cc2', 'pool_address': '0x3d3f13f2529ec3c84b2940155effbf9b39a8f3ec'}, {'pair_name': 'USDC-eb48/DIVER-d5f4', 'pool_address': '0xfe9a776154f30281517d4f06578591911906f4e1'}, {'pair_name': 'MILADY-eb48/WETH-6cc2', 'pool_address': '0x15a8e38942f9e353bec8812763fb3c104c89ecf4'}, {'pair_name': 'yvBOOST-ab9a/WETH-6cc2', 'pool_address': '0x9461173740d27311b176476fa27e94c681b1ea6b'}, {'pair_name': 'LDO-1b32/WETH-6cc2', 'pool_address': '0xc558f600b34a5f69dd2f0d06cb8a88d829b7420a'}, {'pair_name': 'AAVE-dae9/WETH-6cc2', 'pool_address': '0xd75ea151a61d06868e31f8988d28dfe5e9df57b4'}, {'pair_name': 'SOS-aee0/WETH-6cc2', 'pool_address': '0xb84c45174bfc6b8f3eaecbae11dee63114f5c1b2'}, {'pair_name': 'TRU-3784/WETH-6cc2', 'pool_address': '0xfceaaf9792139bf714a694f868a215493461446d'}, {'pair_name': 'BLOCKS-24eb/WETH-6cc2', 'pool_address': '0xdd51121d1efc398b4c09fd0cb84d79ae2c923fc9'}, {'pair_name': 'ICHI-a881/WETH-6cc2', 'pool_address': '0x9cd028b1287803250 ...

# %%
import pytest
from unittest.mock import MagicMock
import requests

def test_invalid_platform():
    with pytest.raises(ValueError):
        get_top_n_pools_for_exchange("invalid_platform")

def test_uniswap_v2_pools():
    requests.post = MagicMock(return_value=MagicMock(json=lambda: {"data": {"pairs": []}}))
    try:
        pairs = get_top_n_pools_for_exchange("uniswap_v2")
        assert pairs is not None
    except Exception as e:
        pytest.fail(f"get_top_5_pools raised an exception: {e}")

def test_uniswap_v3_pools():
    requests.post = MagicMock(return_value=MagicMock(json=lambda: {"data": {"pools": []}}))
    try:
        pairs = get_top_n_pools_for_exchange("uniswap_v3")
        assert pairs is not None
    except Exception as e:
        pytest.fail(f"get_top_5_pools raised an exception: {e}")

def test_sushiswap_pools():
    requests.post = MagicMock(return_value=MagicMock(json=lambda: {"data": {"pairs": []}}))
    try:
        pairs = get_top_n_pools_for_exchange("sushiswap")
        assert pairs is not None
    except Exception as e:
        pytest.fail(f"get_top_5_pools raised an exception: {e}")


test_invalid_platform()
test_uniswap_v2_pools()
test_uniswap_v3_pools()
test_sushiswap_pools()
