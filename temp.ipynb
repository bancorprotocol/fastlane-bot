# %%
from carbon.config import *
from carbon.bot import *

bot = CarbonBot(
    drop_tables=False
)
# Out:
# ConstantProductCurve v2.6 (17/Apr/2023)
# ArbGraph v2.1 (16/Apr/2023)
# TokenScale v1.0 (07/Apr/2022)
# CPCArbOptimizer v3.3 (17/Apr/2023)

# %%
bot.db.seed_pools()
# Out:
# 2023-04-19 06:26:56,751 - fastlane - WARNING - 'NoneType' object is not a mapping
# 2023-04-19 06:27:16,107 - fastlane - WARNING - 'NoneType' object is not a mapping
# 2023-04-19 06:27:22,522 - fastlane - WARNING - execution reverted: execution reverted
# 2023-04-19 06:37:05,772 - fastlane - WARNING - ("The function 'reserveTokens' was not found in this contract's ABI. ", 'Here is a list of all of the function names found: ', 'burn, collect, collectProtocol, factory, fee, feeGrowthGlobal0X128, feeGrowthGlobal1X128, flash, increaseObservationCardinalityNext, initialize, liquidity, maxLiquidityPerTick, mint, observations, observe, positions, protocolFees, setFeeProtocol, slot0, snapshotCumulativesInside, swap, tickBitmap, tickSpacing, ticks, token0, token1. ', 'Did you mean to call one of those functions?')
# ...

# %%
# Out:
# 2023-04-19 06:19:50,635 - fastlane - WARNING - (psycopg2.errors.ForeignKeyViolation) insert or update on table "pools" violates foreign key constraint "pools_exchange_name_fkey"
# DETAIL:  Key (exchange_name)=(carbon_v1) is not present in table "exchanges".
#
# [SQL: INSERT INTO pools (id, cid, last_updated, last_updated_block, descr, pair_name, exchange_name, fee, tkn0_balance, tkn1_balance, z_0, y_0, "A_0", "B_0", z_1, y_1, "A_1", "B_1", sqrt_price_q96, tick, tick_spacing, liquidity, address, anchor) VALUES (%(id)s, %(cid)s, %(last_updated)s, %(last_updated_block)s, %(descr)s, %(pair_name)s, %(exchange_name)s, %(fee)s, %(tkn0_balance)s, %(tkn1_balance)s, %(z_0)s, %(y_0)s, %(A_0)s, %(B_0)s, %(z_1)s, %(y_1)s, %(A_1)s, %(B_1)s, %(sqrt_price_q96)s, %(tick)s, %(tick_spacing)s, %(liquidity)s, %(address)s, %(anchor)s)]
# ...
